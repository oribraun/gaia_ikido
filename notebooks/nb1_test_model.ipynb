# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys,os
cwd = os.getcwd()
sys.path.append(cwd)
sys.path.append(f'{cwd}/..')
sys.path.append(f'{cwd}/../pipeline')

# %%
from pipeline import IkidoClassifierPipeline

# %%
pipeline = IkidoClassifierPipeline()
# Out:
# Xformers is not installed correctly. If you want to use memorry_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
import pandas as pd

# %%
test_set_path = '/Users/user/repos/gaia_ikido/trainer/data/df_test_hf.csv'
df = pd.read_csv(test_set_path)
df = df.iloc[:,1:]
df.head()
# Out:
#                                            datasheet     category  \
# 0  https://app.ikido.tech/api/datasheet/22872efbd...  Transistors
# 1  https://app.ikido.tech/api/datasheet/4724a2bc2...   Connectors
# 2  https://app.ikido.tech/api/datasheet/5195a1ae2...           IC
# 3  https://app.ikido.tech/api/datasheet/c36b21621...   Connectors
# 4  https://app.ikido.tech/api/datasheet/817b2754d...   Connectors
#
#   sub_category                                       cleaned_text  new_score  \
# 0          NaN  lite on dcc release bns od fc/a lite on techno...   0.993257
# 1          NaN  screw down, locking clip, friction latching an...   0.999056
# 2          NaN  general description the maxp/r/s/t, maxap/ar/a...   0.997420
# 3          NaN  power dense design with high current terminals...   0.999032
# 4          NaN  catalog dimensions are in inches and dimension...   0.999117
#
#      new_label                                            pdf_url  \
# ...

# %%
limit = -1
df['label_deberta'] = ''
df['prob_deberta'] = 0
for i, row in df.iterrows():
    pdf_datasheet_url = row.datasheet
    text = row.raw_text
    output = pipeline(inputs = [{'pdf_datasheet_url':pdf_datasheet_url}])
    # output = pipeline(inputs = [{'pdf_datasheet_text':text}])
    df.loc[i,'label_deberta'] = output[0].label
    df.loc[i,'prob_deberta'] = output[0].score
    print(output, i, row.category)
    if i == limit-1:
        break
# Out:
# [IkidoClassifierOutputs(label='Transistors', score=0.9951876401901245, version='1.0.0')] 0 Transistors
# [IkidoClassifierOutputs(label='Connectors', score=0.9980487823486328, version='1.0.0')] 1 Connectors
# [IkidoClassifierOutputs(label='IC', score=0.9976581335067749, version='1.0.0')] 2 IC
# [IkidoClassifierOutputs(label='Connectors', score=0.9980317950248718, version='1.0.0')] 3 Connectors
# [IkidoClassifierOutputs(label='Connectors', score=0.9979904890060425, version='1.0.0')] 4 Connectors
# [IkidoClassifierOutputs(label='Connectors', score=0.9979904890060425, version='1.0.0')] 5 Connectors
# [IkidoClassifierOutputs(label='Connectors', score=0.9974998831748962, version='1.0.0')] 6 Connectors
# [IkidoClassifierOutputs(label='IC', score=0.9970901012420654, version='1.0.0')] 7 Capacitors
# [IkidoClassifierOutputs(label='Connectors', score=0.9980820417404175, version='1.0.0')] 8 Connectors
# ...

# %%
df[['number_of_pages', 'n_numbers', 'n_tokens', 'n_negative_keywords',  'n_keywords', 'label_deberta', 'prob_deberta', 'category', 'correct_prediction', 'datasheet']].to_csv('test_set_predictions.csv', index=False)

# %%
df.to_csv('test_set_predictions.csv', index=False)

# %%
df['correct_prediction'] = df['category'] == df['label_deberta']

# %%
df

# %%
'raw_text' in list(df.columns)
# Out:
# True

# %%
pdf_datasheet_url = 'https://app.ikido.tech/api/datasheet/9cd85784796b00d29e76deaefc9f8ad43a9c199b268a953546b6027c572e9c6d0713fd4b62cfaf3cb3c0ac07f477668c088f63562542db5ececb7627258d84e7/KEM_T2005_T491-1093550.pdf'
https://app.ikido.tech/api/datasheet/0778cc7ead08b40efe3ab60261581fff57636eaa48b5f7979968f877a83fe730c94920809d6d7a7ccb5d85cd2e14b974e7c9c7bb13e1c5c13c9c56a36c3d04e0/UNCH_S_Z0000002162_1-2524880.pdf
https://app.ikido.tech/api/datasheet/cea6c1a02cc079345cd86deab8f0f715e61b71cfb5560bed922e357992f6dff0ca32fc27ea23251bac8760d1e0aca74a20de1aa515839972bd15991b7532b940/AM3G-NZ.pdf
https://app.ikido.tech/api/datasheet/537873cbbf28b61d7fe4967b59840a67488f8f6e60175b26c5945946f9297146c00f21e9e48b8fb8ec169e3a36d29bb280e06e5dc0c7640880052693db743755/cr.pdf
https://app.ikido.tech/api/datasheet/34768633a6690d049c95082bcb5868122f0d61a58e0d97579e282008385cdec26ba3c7643f6ca3ac818a4e9402d15368de49f714bf484dae3fd1c03e25f734e3/cr-1858361.pdf
https://app.ikido.tech/api/datasheet/537873cbbf28b61d7fe4967b59840a67488f8f6e60175b26c5945946f9297146c00f21e9e48b8fb8ec169e3a36d29bb280e06e5dc0c7640880052693db743755/cr.pdf
https://app.ikido.tech/api/datasheet/5417e13e19d4ebce7125f17af58b726a6969398fb92a071b6da8421421291efdac50368f70509bcb36dcf5ba88f1e912410dac2626beb3923cb7bce74f63df48/CRxxxxx.pdf
https://app.ikido.tech/api/datasheet/34768633a6690d049c95082bcb5868122f0d61a58e0d97579e282008385cdec26ba3c7643f6ca3ac818a4e9402d15368de49f714bf484dae3fd1c03e25f734e3/cr-1858361.pdf
'''

data_sheets = [i for i in data_sheets.split('\n') if i]

# %%
# pdf_datasheet_url = 'https://app.ikido.tech/api/datasheet/9cd85784796b00d29e76deaefc9f8ad43a9c199b268a953546b6027c572e9c6d0713fd4b62cfaf3cb3c0ac07f477668c088f63562542db5ececb7627258d84e7/KEM_T2005_T491-1093550.pdf'
inputs = []
for i in range(10):
    if i <5:
        inputs.append({'pdf_datasheet_url':data_sheets[i]})
    else:
        inputs.append({'pdf_datasheet_url':non_data_sheets[i-5]}) 



out = pipeline(inputs = inputs)

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=['number_of_pages', 'n_numbers', 'n_lines', 'n_tokens', 'n_negative_keywords',  'n_keywords', 'n_images', 'n_chapters', 'negative_keywords', 'keywords','label', 'score', 'text'])

for p in pipeline.preprocessor.predictables:
    row = [p.features.number_of_pages, p.features.n_numbers,p.features.n_lines_normalized, p.features.n_tokens,  p.features.n_negative_keywords, p.features.n_keywords, p.features.n_images, len(p.features.table_of_content), p.features.negative_keywords, p.features.keywords, p.category_label, p.category_score, p.features.raw_text[:1000]]
    df.loc[len(df)] = row

# %%
5/3
# Out:
# 1.6666666666666667

# %%
df.head(10)
# Out:
#   number_of_pages n_numbers n_lines n_tokens n_negative_keywords n_keywords  \
# 0               9       182     792     2195                   0        215
# 1               3       169     404      270                   0          4
# 2              16       120    1816     5397                   0         60
# 3               1         2       3        6                   0          0
# 4               8       142     574     1803                   0         33
# 5               2        41     109      490                  16          3
# 6               2         4       5       17                   0          1
# 7               3        14       4       28                   0          1
# 8               3        24     115      471                  15          6
# 9               2         9       6       23                   0          1
#
#   n_images n_chapters                                  negative_keywords  \
# ...

# %%
p =  pipeline.preprocessor.predictables[1]
p.features.n_images
# Out:
# 4
