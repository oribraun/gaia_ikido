# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys,os
cwd = os.getcwd()
sys.path.append(cwd)
sys.path.append(f'{cwd}/..')
sys.path.append(f'{cwd}/../pipeline')

# %%
from pipeline import IkidoClassifierPipeline

# %%
pipeline = IkidoClassifierPipeline()
# Out:
# Xformers is not installed correctly. If you want to use memorry_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
pdf_datasheet_url = 'https://app.ikido.tech/api/datasheet/9cd85784796b00d29e76deaefc9f8ad43a9c199b268a953546b6027c572e9c6d0713fd4b62cfaf3cb3c0ac07f477668c088f63562542db5ececb7627258d84e7/KEM_T2005_T491-1093550.pdf'
pipeline(inputs = [{'pdf_datasheet_url':pdf_datasheet_url}])
# Out:
# ['{"label": "Capacitors", "score": 0.9980541467666626, "version": "1.0.0", "forced": false, "force_reason": "", "predictor_label": "Capacitors"}']

# %%
vars(pipeline.preprocessor.predictables[0].features)
# Out:
# {'pdf_url': 'https://app.ikido.tech/api/datasheet/537873cbbf28b61d7fe4967b59840a67488f8f6e60175b26c5945946f9297146c00f21e9e48b8fb8ec169e3a36d29bb280e06e5dc0c7640880052693db743755/cr.pdf',
#  'table_of_content': [],
#  'number_of_pages': 9,
#  'meta_data': {'format': 'PDF 1.6',
#   'title': 'CR Series Thick Film Chip Resistors',
#   'author': 'Bourns, Inc.',
#   'subject': 'Bourns® Chip Resistors',
#   'keywords': '',
#   'creator': '',
#   'producer': 'Acrobat Distiller 20.0 (Macintosh)',
#   'creationDate': "D:20211112145737-08'00'",
#   'modDate': "D:20211112150208-08'00'",
#   'trapped': '',
#   'encryption': None},
#  'image_list': [],
#  'table_list': [],
#  'n_images': 0,
#  'n_tables': 0,
#  'raw_text': 'CR Series - Thick Film Chip Resistors10CFeatures■ RoHS compliant*■ Tight tolerance of bottom electrode width■ 1 % and 5 % tolerance options■ Three layer termination process with nickel barrier helps prevent leaching and provides excellent solderability■ Tape and reel packagingAdditional InformationClick these links for more information:PRODUCT SELECTORTECHNICALLIBRARYINVENTORYSAMPLESCONTACTElectrical CharacteristicsCharacteristicModel No.CR01005CR0201CR0402CR0603CR0805CR1206CR2010CR2512Power Rating  @ 70 °C1/32 W1/20 W1/16 W1/10 W1/8 W1/4 W1/2 W1 WOperating  Temp. Range-55 °C to +125 °C-55 °C to +155 °CDerated to  Zero Load @+125 °C+155 °CMax. Working Voltage15 V30 V50 V75 V150 V200 V200 V200 VMax. Overload Voltage30 V50 V100 V150 V300 V400 V400 V400 VResistance  Tolerance±1 %, ±5 %Temperature  Coefficient±1 %(E24 & E96 Series)10 Ω≤R<100 Ω ±300 ppm/°C 100 Ω≤R<1 MΩ ±200 ppm/°C1 Ω≤R<10 Ω -200~+600 ppm/°C 10 Ω≤R≤3 MΩ ±200 ppm/°C1 Ω≤R<10 Ω -200~+500 ppm/°C 10 Ω≤R≤1 MΩ ±100 ppm/°C1 MΩ<R≤10 MΩ ±200 ppm/°C1 Ω≤R<10 Ω ±200 ppm/°C 10 Ω≤R≤1 MΩ ±100 ppm/°C1 MΩ<R≤10 MΩ ±200 ppm/°C1 Ω≤R<10 Ω ±200 ppm/°C 10 Ω≤R≤1 MΩ ±100 ppm/°C1 MΩ<R≤10 MΩ ±200 ppm/°C1 Ω≤R<10 Ω ±200 ppm/°C 10 Ω≤R≤1 MΩ ±100 ppm/°C1 MΩ<R≤10 MΩ ±200 ppm/°C1 Ω≤R<10 Ω ±200 ppm/°C 10 Ω≤R≤1 MΩ ±100 ppm/°C1 MΩ<R≤10 MΩ ±200 ppm/°C1 Ω≤R<10 Ω ±200 ppm/°C 10 Ω≤R≤1 MΩ ±100 ppm/°C1 MΩ<R≤10 MΩ ±200 ppm/°CTemperature  Coefficient±5 %(E24 Series)10 Ω≤R<100 Ω ±300 ppm/°C 100 Ω≤R≤1 MΩ ±200 ppm/°C1 Ω≤R<10 Ω -200~+600 ppm/°C 10 Ω≤R≤10 MΩ ±200 ppm/°C1 Ω≤R<10 Ω -200~+500 ppm/°C 10 Ω≤R≤10 MΩ ±200 ppm/°C10 MΩ<R≤20 MΩ ±400 ppm/°C1 Ω≤R<10 Ω ±400 ppm/°C 10 Ω≤R≤10 MΩ ±200 ppm/°C10 MΩ<R≤20 MΩ ±400 ppm/°C1 Ω≤R<10 Ω ±400 ppm/°C 10 Ω≤R≤10 MΩ ±200 ppm/°C10 MΩ<R≤20 MΩ ±400 ppm/°C1 Ω≤R<10 Ω ±400 ppm/°C 10 Ω≤R≤10 MΩ ±200 ppm/°C10 MΩ<R≤20 MΩ ±400 ppm/°C1 Ω≤R<10 Ω ±400 ppm/°C 10 Ω≤R≤10 MΩ ±200 ppm/°C10 MΩ<R≤20 MΩ ±400 ppm/°C1 Ω≤R<10 Ω ±400 ppm/°C 10 Ω≤R≤10 MΩ ±200 ppm/°C10 MΩ<R≤20 MΩ ±400 ppm/°CZero Ohm Jumper50 milliohms max.Rated Current0.5 A1 A2 AMax. Overload Current1 A2.5 A5 AEnvironmental CharacteristicsMoisture Sensitivity Level ..........................................................................................................................................................................1*RoHS Directive 2015/863, Mar 31, 2015 and Annex.Specifications are subject to change without notice. Users should verify actual device performance in their specific applications. The products described herein and this document are subject to specific legal disclaimers as set forth on the last page of this document, and at www.bourns.com/docs/legal/disclaimer.pdf.WARNING Cancer and Reproductive Harmwww.P65Warnings.ca.gov CR Series - Thick Film Chip ResistorsProduct DimensionsModelLWCDTCR010050.40 ± 0.02(.016 ± .0008)0.20 ± 0.03(.008 ± .001)0.10 ± 0.03(.004 ± .001)0.10 ± 0.03(.004 ± .001)0.13 ± 0.02(.009 ± .0008)CR02010.60 ± 0.03(.024 ± .001)0.30 ± 0.03(.012 ± .001)0.10 ± 0.05(.004 ± .002)0.15 ± 0.05(.006 ± .002)0.23 ± 0.03(.009 ± .001)CR04021.00 ± 0.05(.039 ± .002)0.50 ± 0.05(.020 ± .002)0.20 ± 0.10(.008 ± .004)0.25 ± 0.10(.010 ± .004)0.32 ± 0.05(.013 ± .002)CR06031.60 ± 0.10(.063 ± .004)0.80 ± 0.10(.031 ± .004)0.30 ± 0.20(.012 ± .008)0.30 ± 0.20(.012 ± .008)0.45 ± 0.10(.018 ± .004)CR08052.00 ± 0.10(.079 ± .004)1.25 ± 0.10(.049 ± .004)0.40 ± 0.20(.016 ± .008)0.40 ± 0.20(.016 ± .008)0.50 ± 0.10(.020 ± .004)CR12063.10 ± 0.10(.122 ± .004)1.55 ± 0.10(.061 ± .004)0.50 ± 0.30(.020 ± .012)0.40 ± 0.20(.016 ± .008)0.55 ± 0.10(.022 ± .004)CR20105.00 ± 0.15(.197 ± .006)2.50 ± 0.15(.098 ± .006)0.60 ± 0.30(.024 ± .012)0.50 ± 0.25(.020 ± .010)0.60 ± 0.10(.024 ± .004)CR25126.30 ± 0.20(.248 ± .008)3.20 ± 0.20(.126 ± .008)0.60 ± 0.30(.024 ± .012)0.50 ± 0.25(.020 ± .010)0.60 ± 0.10(.024 ± .004)LWCTCDDIMENSIONS:MM(INCHES)DIMENSIONS:MM(INCHES)Recommended Pad LayoutModelabcCR010050.15 ~ 0.20(.006 ~ .008)0.50 ~ 0.70(.020 ~ .028)0.20 ~ 0.25(.008 ~ .010)CR02010.25 ~ 0.30(.010 ~ .012)0.70 ~ 0.90(.028 ~ .035)0.30 ~ 0.40(.012  ...
#  'text_cleaned': 'cr series thick film chip resistors\nc\nfeatures\nrohs compliant*\ntight tolerance bottom electrode width\n% % tolerance options\nthree layer termination process\nnickel barrier helps prevent leaching\nprovides excellent solderability\ntape reel packaging\nadditional information\nclick links information:\nproduct\nselector\ntechnical\nlibrary\ninventory\nsamples\ncontact\nelectrical characteristics\ncharacteristic\nmodel no.\ncr\ncr\ncr\ncr\ncr\ncr\ncr\ncr\npower rating\n@ °c\n/ w\n/ w\n/ w\n/ w\n/ w\n/ w\n/ w\nw\noperating\ntemp. range\n°c + °c\n°c + °c\nderated\nzero load @\n+ °c\n+ °c\nmax. working\nvoltage\nv\nv\nv\nv\nv\nv\nv\nv\nmax. overload\nvoltage\nv\nv\nv\nv\nv\nv\nv\nv\nresistance\ntolerance\n± %, ± %\ntemperature\ncoefficient\n± %\n(e & e\nseries)\nω≤r< ω\n± ppm/°c\nω≤r< mω\n± ppm/°c\nω≤r< ω\n~+\nppm/°c\nω≤r≤ mω\n± ppm/°c\nω≤r< ω\n~+\nppm/°c\nω≤r≤ mω\n± ppm/°c\nmω<r≤ mω\n± ppm/°c\nω≤r< ω\n± ppm/°c\nω≤r≤ mω\n± ppm/°c\nmω<r≤ mω\n± ppm/°c\nω≤r< ω\n± ppm/°c\nω≤r≤ mω\n± ppm/°c\nmω<r≤ mω\n± ppm/°c\nω≤r< ω\n± ppm/°c\nω≤r≤ mω\n± ppm/°c\nmω<r≤ mω\n± ppm/°c\nω≤r< ω\n± ppm/°c\nω≤r≤ mω\n± ppm/°c\nmω<r≤ mω\n± ppm/°c\nω≤r< ω\n± ppm/°c\nω≤r≤ mω\n± ppm/°c\nmω<r≤ mω\n± ppm/°c\ntemperature\ncoefficient\n± %\n(e series)\nω≤r< ω\n± ppm/°c\nω≤r≤ mω\n± ppm/°c\nω≤r< ω\n~+\nppm/°c\nω≤r≤ mω\n± ppm/°c\nω≤r< ω\n~+\nppm/°c\nω≤r≤ mω\n± ppm/°c\nmω<r≤ mω\n± ppm/°c\nω≤r< ω\n± ppm/°c\nω≤r≤ mω\n± ppm/°c\nmω<r≤ mω\n± ppm/°c\nω≤r< ω\n± ppm/°c\nω≤r≤ mω\n± ppm/°c\nmω<r≤ mω\n± ppm/°c\nω≤r< ω\n± ppm/°c\nω≤r≤ mω\n± ppm/°c\nmω<r≤ mω\n± ppm/°c\nω≤r< ω\n± ppm/°c\nω≤r≤ mω\n± ppm/°c\nmω<r≤ mω\n± ppm/°c\nω≤r< ω\n± ppm/°c\nω≤r≤ mω\n± ppm/°c\nmω<r≤ mω\n± ppm/°c\nzero ohm\njumper\nmilliohms max.\nrated current\n.\nmax. overload\ncurrent\n.\nenvironmental characteristics\nmoisture sensitivity level\n*rohs directive /, mar , annex.\nspecifications subject change without notice. users verify actual device performance specific\napplications. products described herein document subject specific legal disclaimers set forth last\npage document,\nwarning\ncancer reproductive harm\ncr series thick film chip resistors\nproduct dimensions\nmodel\nl\nw\nc\ncr\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\ncr\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\ncr\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\ncr\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\ncr\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\ncr\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\ncr\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\ncr\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\n. ± .\n(. ± .)\nl\nw\nc\nc\ndimensions:\nmm\n(inches)\ndimensions:\nmm\n(inches)\nrecommended pad layout\nmodel\nb\nc\ncr\n. ~ .\n(. ~ .)\n. ~ .\n(. ~ .)\n. ~ .\n(. ~ .)\ncr\n. ~ .\n(. ~ .)\n. ~ .\n(. ~ .)\n. ~ .\n(. ~ .)\ncr\n. ~ .\n(. ~ .)\n. ~ .\n(. ~ .)\n. ~ .\n(. ~ .)\ncr\n. ~ .\n(. ~ .)\n. ~ .\n(. ~ .)\n. ~ .\n(. ~ .)\ncr\n. ~ .\n(. ~ .)\n. ~ .\n(. ~ .)\n. ~ .\n(. ~ .)\ncr\n. ~ .\n(. ~ .)\n. ~ .\n(. ~ .)\n. ~ .\n(. ~ .)\ncr\n. ~ .\n(. ~ .)\n. ~ .\n(. ± .)\n. ~ .\n(. ~ .)\ncr\n. ~ .\n(. ~ .)\n. ~ .\n(. ~ .)\n. ~ .\n(. ~ .)\nresistor\nb\nc\nspeciﬁcations subject change without notice.\nusers verify actual device performance speciﬁc applications.\nproducts described herein document subject speciﬁc legal disclaimers set forth last page document,\ncr series thick film chip resistors\nspeciﬁcations subject change without notice.\nusers verify actual device performance speciﬁc applications.\nproducts described herein document subject speciﬁc legal disclaimers set forth last page document,\nsoldering profile\ntime (seconds)\ntemperature (°c)\nseconds\nseconds\n°c peak\n°c\n°c\n°c\nramp\n°c/second\n°c\nmaximum seconds\n+ °c + °c\nramp\n°c/second maximum\nseconds min ...
#  'tokens': ['CR',
#   'Series',
#   '-',
#   'Thick',
#   'Film',
#   'Chip',
#   'Resistors10CFeatures■',
#   'RoHS',
#   'compliant*■',
#   'Tight',
#   'tolerance',
#   'of',
#   'bottom',
#   'electrode',
#   'width■',
#   '1',
#   '%',
#   'and',
#   '5',
#   '%',
#   'tolerance',
#   'options■',
#   'Three',
#   'layer',
#   'termination',
#   'process',
#   'with',
#   'nickel',
#   'barrier',
#   'helps',
#   'prevent',
#   'leaching',
#   'and',
#   'provides',
#   'excellent',
#   'solderability■',
#   'Tape',
#   'and',
#   'reel',
#   'packagingAdditional',
#   'InformationClick',
#   'these',
#   'links',
#   'for',
#   'more',
#   'information:PRODUCT',
#   'SELECTORTECHNICALLIBRARYINVENTORYSAMPLESCONTACTElectrical',
#   'CharacteristicsCharacteristicModel',
#   'No.CR01005CR0201CR0402CR0603CR0805CR1206CR2010CR2512Power',
#   'Rating',
#   '@',
#   '70',
#   '°C1/32',
#   'W1/20',
#   'W1/16',
#   'W1/10',
#   'W1/8',
#   'W1/4',
#   'W1/2',
#   'W1',
#   'WOperating',
#   'Temp.',
#   'Range-55',
#   '°C',
#   'to',
#   '+125',
#   '°C-55',
#   '°C',
#   'to',
#   '+155',
#   '°CDerated',
#   'to',
#   'Zero',
#   'Load',
#   '@+125',
#   '°C+155',
#   '°CMax.',
#   'Working',
#   'Voltage15',
#   'V30',
#   'V50',
#   'V75',
#   'V150',
#   'V200',
#   'V200',
#   'V200',
#   'VMax.',
#   'Overload',
#   'Voltage30',
#   'V50',
#   'V100',
#   'V150',
#   'V300',
#   'V400',
#   'V400',
#   'V400',
#   'VResistance',
#   'Tolerance±1',
#   '%,',
#   '±5',
#   '%Temperature',
#   'Coefficient±1',
#   '%(E24',
#   '&',
#   'E96',
#   'Series)10',
#   'Ω≤R<100',
#   'Ω',
#   '±300',
#   'ppm/°C',
#   '100',
#   'Ω≤R<1',
#   'MΩ',
#   '±200',
#   'ppm/°C1',
#   'Ω≤R<10',
#   'Ω',
#   '-200~+600',
#   'ppm/°C',
#   '10',
#   'Ω≤R≤3',
#   'MΩ',
#   '±200',
#   'ppm/°C1',
#   'Ω≤R<10',
#   'Ω',
#   '-200~+500',
#   'ppm/°C',
#   '10',
#   'Ω≤R≤1',
#   'MΩ',
#   '±100',
#   'ppm/°C1',
#   'MΩ<R≤10',
#   'MΩ',
#   '±200',
#   'ppm/°C1',
#   'Ω≤R<10',
#   'Ω',
#   '±200',
#   'ppm/°C',
#   '10',
#   'Ω≤R≤1',
#   'MΩ',
#   '±100',
#   'ppm/°C1',
#   'MΩ<R≤10',
#   'MΩ',
#   '±200',
#   'ppm/°C1',
#   'Ω≤R<10',
#   'Ω',
#   '±200',
#   'ppm/°C',
#   '10',
#   'Ω≤R≤1',
#   'MΩ',
#   '±100',
#   'ppm/°C1',
#   'MΩ<R≤10',
#   'MΩ',
#   '±200',
#   'ppm/°C1',
#   'Ω≤R<10',
#   'Ω',
#   '±200',
#   'ppm/°C',
#   '10',
#   'Ω≤R≤1',
#   'MΩ',
#   '±100',
#   'ppm/°C1',
#   'MΩ<R≤10',
#   'MΩ',
#   '±200',
#   'ppm/°C1',
#   'Ω≤R<10',
#   'Ω',
#   '±200',
#   'ppm/°C',
#   '10',
#   'Ω≤R≤1',
#   'MΩ',
#   '±100',
#   'ppm/°C1',
#   'MΩ<R≤10',
#   'MΩ',
#   '±200',
#   'ppm/°C1',
#   'Ω≤R<10',
#   'Ω',
#   '±200',
#   'ppm/°C',
#   '10',
#   'Ω≤R≤1',
#   'MΩ',
#   '±100',
#   'ppm/°C1',
#   'MΩ<R≤10',
#   'MΩ',
#   '±200',
#   'ppm/°CTemperature',
#   'Coefficient±5',
#   '%(E24',
#   'Series)10',
#   'Ω≤R<100',
#   'Ω',
#   '±300',
#   'ppm/°C',
#   '100',
#   'Ω≤R≤1',
#   'MΩ',
#   '±200',
#   'ppm/°C1',
#   'Ω≤R<10',
#   'Ω',
#   '-200~+600',
#   'ppm/°C',
#   '10',
#   'Ω≤R≤10',
#   'MΩ',
#   '±200',
#   'ppm/°C1',
#   'Ω≤R<10',
#   'Ω',
#   '-200~+500',
#   'ppm/°C',
#   '10',
#   'Ω≤R≤10',
#   'MΩ',
#   '±200',
#   'ppm/°C10',
#   'MΩ<R≤20',
#   'MΩ',
#   '±400',
#   'ppm/°C1',
#   'Ω≤R<10',
#   'Ω',
#   '±400',
#   'ppm/°C',
#   '10',
#   'Ω≤R≤10',
#   'MΩ',
#   '±200',
#   'ppm/°C10',
#   'MΩ<R≤20',
#   'MΩ',
#   '±400',
#   'ppm/°C1',
#   'Ω≤R<10',
#   'Ω',
#   '±400',
#   'ppm/°C',
#   '10',
#   'Ω≤R≤10',
#   'MΩ',
#   '±200',
#   'ppm/°C10',
#   'MΩ<R≤20',
#   'MΩ',
#   '±400',
#   'ppm/°C1',
#   'Ω≤R<10',
#   'Ω',
#   '±400',
#   'ppm/°C',
#   '10',
#   'Ω≤R≤10',
#   'MΩ',
#   '±200',
#   'ppm/°C10',
#   'MΩ<R≤20',
#   'MΩ',
#   '±400',
#   'ppm/°C1',
#   'Ω≤R<10',
#   'Ω',
#   '±400',
#   'ppm/°C',
#   '10',
#   'Ω≤R≤10',
#   'MΩ',
#   '±200',
#   'ppm/°C10',
#   'MΩ<R≤20',
#   'MΩ',
#   '±400',
#   'ppm/°C1',
#   'Ω≤R<10',
#   'Ω',
#   '±400',
#   'ppm/°C',
#   '10',
#   'Ω≤R≤10',
#   'MΩ',
#   '±200',
#   'ppm/°C10',
#   'MΩ<R≤20',
#   'MΩ',
#   '±400',
#   'ppm/°CZero',
#   'Ohm',
#   'Jumper50',
#   'milliohms',
#   'max.Rated',
#   'Current0.5',
#   'A1',
#   'A2',
#   'AMax.',
#   'Overload',
#   'Current1',
#   'A2.5',
#   'A5',
#   'AEnvironmental',
#   'CharacteristicsMoisture',
#   'Sensitivity',
#   'Level',
#   '..........................................................................................................................................................................1*RoHS',
#   'Directive',
#   '2015/863,',
#   'Mar',
#   '31,',
#   '2015',
#   'and',
#   'Annex.Specifications',
#   'are',
#   'subject',
#   'to',
#   'change',
#   'without',
#   'notice.',
#   'Users',
#   'should',
#   'verify',
#   'actual',
#   'device',
#   'performance',
#   'in',
#   'their',
#   'specific',
#   'applications.',
#   'The',
#   'products',
#   'described',
#   'herein',
#   'and',
#   'this',
#   'document',
#   'are',
#   'subject',
#   'to',
#   'specific',
#   'legal',
#   'disclaimers',
#   'as',
#   'set',
#   'forth',
#   'on',
#   'the',
#   'last',
#   'page',
#   'of',
#   'this',
#   'document,',
#   'and',
#   'at',
#   'www.bourns.com/docs/legal/disclaimer.pdf.WARNING',
#   'Cancer',
#   'and',
#   'Reproductive',
#   'Harmwww.P65Warnings.ca.gov',
#   'CR',
#   'Series',
#   '-',
#   'Thick',
#   'Film',
#   'Chip',
#   'ResistorsProduct',
#   'DimensionsModelLWCDTCR010050.40',
#   '±',
#   '0.02(.016',
#   '±',
#   '.0008)0.20',
#   '±',
#   '0.03(.008',
#   '±',
#   '.001)0.10',
#   '±',
#   '0.03(.004',
#   '±',
#   '.001)0.10',
#   '±',
#   '0.03(.004',
#   '±',
#   '.001)0.13',
#   '±',
#   '0.02(.009',
#   '±',
#   '.0008)CR02010.60',
#   '±',
#   '0.03(.024',
#   '±',
#   '.001)0.30',
#   '±',
#   '0.03(.012',
#   '±',
#   '.001)0.10',
#   '±',
#   '0.05(.004',
#   '±',
#   '.002)0.15',
#   '±',
#   '0.05(.006',
#   '±',
#   '.002)0.23',
#   '±',
#   '0.03(.009',
#   '±',
#   '.001)CR04021.00',
#   '±',
#   '0.05(.039',
#   '±',
#   '.002)0.50',
#   '±',
#   '0.05(.020',
#   '±',
#   '.002)0.20',
#   '±',
#   '0.10(.008',
#   '±',
#   '.004)0.25',
#   '±',
#   '0.10(.010',
#   '±',
#   '.004)0.32',
#   '±',
#   '0.05(.013',
#   '±',
#   '.002)CR06031.60',
#   '±',
#   '0.10(.063',
#   '±',
#   '.004)0.80',
#   '±',
#   '0.10(.031',
#   '±',
#   '.004)0.30',
#   '±',
#   '0.20(.012',
#   '±',
#   '.008)0.30',
#   '±',
#   '0.20(.012',
#   '±',
#   '.008)0.45',
#   '±',
#   '0.10(.018',
#   '±',
#   '.004)CR08052.00',
#   '±',
#   '0.10(.079',
#   '±',
#   '.004)1.25',
#   '±',
#   '0.10(.049',
#   '±',
#   '.004)0.40',
#   '±',
#   '0.20(.016',
#   '±',
#   '.008)0.40',
#   '±',
#   '0.20(.016',
#   '±',
#   '.008)0.50',
#   '±',
#   '0.10(.020',
#   '±',
#   '.004)CR12063.10',
#   '±',
#   '0.10(.122',
#   '±',
#   '.004)1.55',
#   '±',
#   '0.10(.061',
#   '±',
#   '.004)0.50',
#   '±',
#   '0.30(.020',
#   '±',
#   '.012)0.40',
#   '±',
#   '0.20(.016',
#   '±',
#   '.008)0.55',
#   '±',
#   '0.10(.022',
#   '±',
#   '.004)CR20105.00',
#   '±',
#   '0.15(.197',
#   '±',
#   '.006)2.50',
#   '±',
#   '0.15(.098',
#   '±',
#   '.006)0.60',
#   '±',
#   '0.30(.024',
#   '±',
#   '.012)0.50',
#   '±',
#   '0.25(.020',
#   '±',
#   '.010)0.60',
#   '±',
#   '0.10(.024',
#   '±',
#   '.004)CR25126.30',
#   '±',
#   '0.20(.248',
#   '±',
#   '.008)3.20',
#   '±',
#   '0.20(.126',
#   '±',
#   '.008)0.60',
#   '±',
#   '0.30(.024',
#   '±',
#   '.012)0.50',
#   '±',
#   '0.25(.020',
#   '±',
#   '.010)0.60',
#   '±',
#   '0.10(.024',
#   '±',
#   '.004)LWCTCDDIMENSIONS:MM(INCHES)DIMENSIONS:MM(INCHES)Recommended',
#   'Pad',
#   'LayoutModelabcCR010050.15',
#   '~',
#   '0.20(.006',
#   '~',
#   '.008)0.50',
#   '~',
#   '0.70(.020',
#   '~',
#   '.028)0.20',
#   '~',
#   '0.25(.008',
#   '~',
#   '.010)CR02010.25',
#   '~',
#   '0.30(.010',
#   '~',
#   '.012)0.70',
#   '~',
#   '0.90(.028',
#   '~',
#   '.035)0.30',
#   '~',
#   '0.40(.012',
#   '~',
#   '.016)CR04020.50',
#   '~',
#   '0.60(.020',
#   '~',
#   '.024)1.40',
#   '~',
#   '1.60(.055',
#   '~',
#   '.063)0.40',
#   '~',
#   '0.60(.012',
#   '~',
#   '.024)CR06030.70',
#   '~',
#   '0.90(.028',
#   '~',
#   '.035)2.00',
#   '~',
#   '2.20(.079',
#   '~',
#   '.087)0.80',
#   '~',
#   '1.00(.031',
#   '~',
#   '.039)CR08051.00',
#   '~',
#   '1.40(.039',
#   '~',
#   '.055)3.20',
#   '~',
#   '3.80(.126',
#   '~',
#   '.150)0.90',
#   '~',
#   '1.40(.035',
#   '~',
#   '.055)CR12062.00',
#   '~',
#   '2.40(.079',
#   '~',
#   '.094)4.40',
#   '~',
#   '5.00(.173',
#   '~',
#   '.197)1.20',
#   '~',
#   '1.80(.047',
#   '~',
#   '.071)CR20103.30',
#   '~',
#   '3.70(.130',
#   '~',
#   '.146)5.70',
#   '~',
#   '6.50(.224',
#   '±',
#   '.256)2.30',
#   '~',
#   '3.50(.091',
#   '~',
#   '.138)CR25123.60',
#   '~',
#   '4.00(.142',
#   '~',
#   '.157)7.60',
#   '~',
#   '8.60(.299',
#   '~',
#   '.339)2.30',
#   '~',
#   '3.50(.091',
#   '~',
#   '.138)aRESISTORbcSpeciﬁcations',
#   'are',
#   'subject',
#   'to',
#   'change',
#   'without',
#   'notice.Users',
#   'should',
#   'verify',
#   'actual',
#   'device',
#   'performance',
#   'in',
#   'their',
#   'speciﬁc',
#   'applications.',
#   'The',
#   'products',
#   'described',
#   'herein',
#   'and',
#   'this',
#   'document',
#   'are',
#   'subject',
#   'to',
#   'speciﬁc',
#   'legal',
#   'disclaimers',
#   'as',
#   'set',
#   'forth',
#   'on',
#   'the',
#   'last',
#   'page',
#   'of',
#   'this',
#   'document,',
#   'and',
#   'at',
#   'www.bourns.com/docs/legal/disclaimer.pdf.',
#   'CR',
#   'Series',
#   '-',
#   'Thick',
#   'Film',
#   'Chip',
#   'ResistorsSpeciﬁcations',
#   'are',
#   'subject',
#   'to',
#   'change',
#   'without',
#   'notice.Users',
#   'should',
#   'verify',
#   'actual',
#   'device',
#   'performance',
#   'in',
#   'their',
#   'speciﬁc',
#   'applications.',
#   'The',
#   'products',
#   'described',
#   'herein',
#   'and',
#   'this',
#   'document',
#   'are',
#   'subject',
#   'to',
#   'speciﬁc',
#   'legal',
#   'disclaimers',
#   'as',
#   'set',
#   'forth',
#   'on',
#   'the',
#   'last',
#   'page',
#   'of',
#   'this',
#   'document,',
#   'and',
#   'at',
#   'www.bourns.com/docs/legal/disclaimer.pdf.Soldering',
#   'Profile2575125175225275050100150200250300Time',
#   '(Seconds)Temperature',
#   '(°C)60',
#   '-',
#   '120',
#   'seconds60',
#   '-',
#   '90seconds260',
#   '°C',
#   'peak190',
#   '°C150',
#   '°C220',
#   '°CRamp',
#   'Down6',
#   '°C/second',
#   '255',
#   '°CMaximum',
#   'of',
#   '20',
#   'seconds',
#   'between',
#   '+255',
#   '°C',
#   'and',
#   '+260',
#   '°CRamp',
#   'Up3',
#   '°C/second',
#   'maximum10',
#   'seconds',
#   'minimum<1><1>Derating',
#   'Curve100806040200Power',
#   'Ratio',
#   '(%)-552040608070125CR01005,CR0201CR0402~CR2512155100120140160Ambient',
#   'Temperature',
#   '(°C)',
#   'CR',
#   'Series',
#   '-',
#   'Thick',
#   'Film',
#   'Chip',
#   'ResistorsPerformance',
#   'CharacteristicsTestProcedure',
#   '(IEC',
#   '60115-1)Test',
#   'Limits',
#   '∆RShort',
#   'Time',
#   'Overload2.5',
#   'x',
#   'rated',
#   'voltage',
#   'for',
#   '5',
#   'seconds≤±',
#   '(1',
#   '%',
#   '+',
#   '0.05',
#   'Ω',
#   ')Remarks:CR01005,',
#   'CR0201',
#   '..................',
#   '±',
#   '(3',
#   '%',
#   '+',
#   '0.1',
#   'Ω)CR0402',
#   '...................................',
#   '±',
#   '(2',
#   '%',
#   '+',
#   '0.1',
#   'Ω)0',
#   'Ω',
#   'Jumper',
#   '................................',
#   '50',
#   'mΩ',
#   'or',
#   'lessIntermittent',
#   'Overload3.0',
#   'x',
#   'rated',
#   'voltage',
#   'or',
#   'max.',
#   'overloading',
#   'voltage,',
#   '1',
#   'sec.',
#   '“ON”,',
#   '25',
#   'sec.',
#   '“OFF”,10,000',
#   'cyclesRemarks:CR01005,',
#   'CR0201',
#   '.....................................................',
#   'not',
#   'applicableCR0402',
#   '...............................2.5',
#   'x',
#   'rated',
#   'continuous',
#   'working',
#   'voltage1',
#   '%:',
#   '≤±',
#   '(1',
#   '%',
#   '+',
#   '0.05',
#   'Ω)5',
#   '%:',
#   '≤±',
#   '(3',
#   '%',
#   '+',
#   '0.1',
#   'Ω)Remarks:CR01005,',
#   'CR0201',
#   '..................',
#   '±',
#   '(5',
#   '%',
#   '+',
#   '0.1',
#   'Ω)CR0402',
#   '...................................',
#   '±',
#   '(3',
#   '%',
#   '+',
#   '0.1',
#   'Ω)0',
#   'Ω',
#   'Jumper',
#   '..............................',
#   '100',
#   'mΩ',
#   'or',
#   'lessLoad',
#   'Life1000',
#   'hours',
#   'at',
#   'rated',
#   'voltage,',
#   '70',
#   '℃',
#   ',',
#   '1.5',
#   'hours',
#   '“ON',
#   '“,',
#   '0.5',
#   'hour',
#   '“OFF”1',
#   '%:',
#   '≤±',
#   '(1',
#   '%',
#   '+',
#   '0.05',
#   'Ω)5',
#   '%:',
#   '≤±',
#   '(3',
#   '%',
#   '+',
#   '0.1',
#   'Ω)Remarks:CR01005,',
#   'CR0201',
#   '..................',
#   '±',
#   '(5',
#   '%',
#   '+',
#   '0.1',
#   'Ω)CR0402',
#   '...................................',
#   '±',
#   '(3',
#   '%',
#   '+',
#   '0.1',
#   'Ω)0',
#   'Ω',
#   'Jumper',
#   '..............................',
#   '100',
#   'mΩ',
#   'or',
#   'lessLoad',
#   'Life',
#   'Humidity1000',
#   'hours',
#   'at',
#   'rated',
#   'voltage',
#   ',',
#   '40±2',
#   '℃,90~95',
#   '%',
#   'RH',
#   '1.5',
#   'hours',
#   '“ON',
#   '“,',
#   '0.5',
#   'hour',
#   '“OFF”1',
#   '%:',
#   '≤±',
#   '(1',
#   '%',
#   '+',
#   '0.05',
#   'Ω)5',
#   '%:',
#   '≤±',
#   '(3',
#   '%',
#   '+',
#   '0.1',
#   'Ω)Remarks:CR01005,',
#   'CR0201',
#   '..................',
#   '±',
#   '(5',
#   '%',
#   '+',
#   '0.1',
#   'Ω)CR0402',
#   '...................................',
#   '±',
#   '(3',
#   '%',
#   '+',
#   '0.1',
#   'Ω)0',
#   'Ω',
#   'Jumper',
#   '..............................',
#   '100',
#   'mΩ',
#   'or',
#   'lessRapid',
#   'Change',
#   'of',
#   'Temperature-55',
#   '℃',
#   '(30',
#   'min.)',
#   '/',
#   '+155',
#   '℃',
#   '(30',
#   'min.)',
#   '5',
#   'cycles1',
#   '%:',
#   '≤±',
#   '(0.5',
#   '%',
#   '+',
#   '0.05',
#   'Ω)5',
#   '%:',
#   '≤±',
#   '(1',
#   '%',
#   ...],
#  'lines': ['CR Series - Thick Film Chip Resistors',
#   '10C',
#   'Features',
#   '■ RoHS compliant*',
#   '■ Tight tolerance of bottom electrode width',
#   '■ 1 % and 5 % tolerance options',
#   '■ Three layer termination process with ',
#   'nickel barrier helps prevent leaching and ',
#   'provides excellent solderability',
#   '■ Tape and reel packaging',
#   'Additional Information',
#   'Click these links for more information:',
#   'PRODUCT ',
#   'SELECTOR',
#   'TECHNICAL',
#   'LIBRARY',
#   'INVENTORY',
#   'SAMPLES',
#   'CONTACT',
#   'Electrical Characteristics',
#   'Characteristic',
#   'Model No.',
#   'CR01005',
#   'CR0201',
#   'CR0402',
#   'CR0603',
#   'CR0805',
#   'CR1206',
#   'CR2010',
#   'CR2512',
#   'Power Rating  ',
#   '@ 70 °C',
#   '1/32 W',
#   '1/20 W',
#   '1/16 W',
#   '1/10 W',
#   '1/8 W',
#   '1/4 W',
#   '1/2 W',
#   '1 W',
#   'Operating  ',
#   'Temp. Range',
#   '-55 °C to +125 °C',
#   '-55 °C to +155 °C',
#   'Derated to  ',
#   'Zero Load @',
#   '+125 °C',
#   '+155 °C',
#   'Max. Working ',
#   'Voltage',
#   '15 V',
#   '30 V',
#   '50 V',
#   '75 V',
#   '150 V',
#   '200 V',
#   '200 V',
#   '200 V',
#   'Max. Overload ',
#   'Voltage',
#   '30 V',
#   '50 V',
#   '100 V',
#   '150 V',
#   '300 V',
#   '400 V',
#   '400 V',
#   '400 V',
#   'Resistance  ',
#   'Tolerance',
#   '±1 %, ±5 %',
#   'Temperature  ',
#   'Coefficient',
#   '±1 %',
#   '(E24 & E96 ',
#   'Series)',
#   '10 Ω≤R<100 Ω ',
#   '±300 ppm/°C ',
#   '100 Ω≤R<1 MΩ ',
#   '±200 ppm/°C',
#   '1 Ω≤R<10 Ω ',
#   '-200~+600 ',
#   'ppm/°C ',
#   '10 Ω≤R≤3 MΩ ',
#   '±200 ppm/°C',
#   '1 Ω≤R<10 Ω ',
#   '-200~+500 ',
#   'ppm/°C ',
#   '10 Ω≤R≤1 MΩ ',
#   '±100 ppm/°C',
#   '1 MΩ<R≤10 MΩ ',
#   '±200 ppm/°C',
#   '1 Ω≤R<10 Ω ',
#   '±200 ppm/°C ',
#   '10 Ω≤R≤1 MΩ ',
#   '±100 ppm/°C',
#   '1 MΩ<R≤10 MΩ ',
#   '±200 ppm/°C',
#   '1 Ω≤R<10 Ω ',
#   '±200 ppm/°C ',
#   '10 Ω≤R≤1 MΩ ',
#   '±100 ppm/°C',
#   '1 MΩ<R≤10 MΩ ',
#   '±200 ppm/°C',
#   '1 Ω≤R<10 Ω ',
#   '±200 ppm/°C ',
#   '10 Ω≤R≤1 MΩ ',
#   '±100 ppm/°C',
#   '1 MΩ<R≤10 MΩ ',
#   '±200 ppm/°C',
#   '1 Ω≤R<10 Ω ',
#   '±200 ppm/°C ',
#   '10 Ω≤R≤1 MΩ ',
#   '±100 ppm/°C',
#   '1 MΩ<R≤10 MΩ ',
#   '±200 ppm/°C',
#   '1 Ω≤R<10 Ω ',
#   '±200 ppm/°C ',
#   '10 Ω≤R≤1 MΩ ',
#   '±100 ppm/°C',
#   '1 MΩ<R≤10 MΩ ',
#   '±200 ppm/°C',
#   'Temperature  ',
#   'Coefficient',
#   '±5 %',
#   '(E24 Series)',
#   '10 Ω≤R<100 Ω ',
#   '±300 ppm/°C ',
#   '100 Ω≤R≤1 MΩ ',
#   '±200 ppm/°C',
#   '1 Ω≤R<10 Ω ',
#   '-200~+600 ',
#   'ppm/°C ',
#   '10 Ω≤R≤10 MΩ ',
#   '±200 ppm/°C',
#   '1 Ω≤R<10 Ω ',
#   '-200~+500 ',
#   'ppm/°C ',
#   '10 Ω≤R≤10 MΩ ',
#   '±200 ppm/°C',
#   '10 MΩ<R≤20 MΩ ',
#   '±400 ppm/°C',
#   '1 Ω≤R<10 Ω ',
#   '±400 ppm/°C ',
#   '10 Ω≤R≤10 MΩ ',
#   '±200 ppm/°C',
#   '10 MΩ<R≤20 MΩ ',
#   '±400 ppm/°C',
#   '1 Ω≤R<10 Ω ',
#   '±400 ppm/°C ',
#   '10 Ω≤R≤10 MΩ ',
#   '±200 ppm/°C',
#   '10 MΩ<R≤20 MΩ ',
#   '±400 ppm/°C',
#   '1 Ω≤R<10 Ω ',
#   '±400 ppm/°C ',
#   '10 Ω≤R≤10 MΩ ',
#   '±200 ppm/°C',
#   '10 MΩ<R≤20 MΩ ',
#   '±400 ppm/°C',
#   '1 Ω≤R<10 Ω ',
#   '±400 ppm/°C ',
#   '10 Ω≤R≤10 MΩ ',
#   '±200 ppm/°C',
#   '10 MΩ<R≤20 MΩ ',
#   '±400 ppm/°C',
#   '1 Ω≤R<10 Ω ',
#   '±400 ppm/°C ',
#   '10 Ω≤R≤10 MΩ ',
#   '±200 ppm/°C',
#   '10 MΩ<R≤20 MΩ ',
#   '±400 ppm/°C',
#   'Zero Ohm ',
#   'Jumper',
#   '50 milliohms max.',
#   'Rated Current',
#   '0.5 A',
#   '1 A',
#   '2 A',
#   'Max. Overload ',
#   'Current',
#   '1 A',
#   '2.5 A',
#   '5 A',
#   'Environmental Characteristics',
#   'Moisture Sensitivity Level ..........................................................................................................................................................................1',
#   '*RoHS Directive 2015/863, Mar 31, 2015 and Annex.',
#   'Specifications are subject to change without notice. Users should verify actual device performance in their specific ',
#   'applications. The products described herein and this document are subject to specific legal disclaimers as set forth on the last ',
#   'page of this document, and at www.bourns.com/docs/legal/disclaimer.pdf.',
#   'WARNING ',
#   'Cancer and Reproductive Harm',
#   'www.P65Warnings.ca.gov',
#   '\x0c ',
#   'CR Series - Thick Film Chip Resistors',
#   'Product Dimensions',
#   'Model',
#   'L',
#   'W',
#   'C',
#   'D',
#   'T',
#   'CR01005',
#   '0.40 ± 0.02',
#   '(.016 ± .0008)',
#   '0.20 ± 0.03',
#   '(.008 ± .001)',
#   '0.10 ± 0.03',
#   '(.004 ± .001)',
#   '0.10 ± 0.03',
#   '(.004 ± .001)',
#   '0.13 ± 0.02',
#   '(.009 ± .0008)',
#   'CR0201',
#   '0.60 ± 0.03',
#   '(.024 ± .001)',
#   '0.30 ± 0.03',
#   '(.012 ± .001)',
#   '0.10 ± 0.05',
#   '(.004 ± .002)',
#   '0.15 ± 0.05',
#   '(.006 ± .002)',
#   '0.23 ± 0.03',
#   '(.009 ± .001)',
#   'CR0402',
#   '1.00 ± 0.05',
#   '(.039 ± .002)',
#   '0.50 ± 0.05',
#   '(.020 ± .002)',
#   '0.20 ± 0.10',
#   '(.008 ± .004)',
#   '0.25 ± 0.10',
#   '(.010 ± .004)',
#   '0.32 ± 0.05',
#   '(.013 ± .002)',
#   'CR0603',
#   '1.60 ± 0.10',
#   '(.063 ± .004)',
#   '0.80 ± 0.10',
#   '(.031 ± .004)',
#   '0.30 ± 0.20',
#   '(.012 ± .008)',
#   '0.30 ± 0.20',
#   '(.012 ± .008)',
#   '0.45 ± 0.10',
#   '(.018 ± .004)',
#   'CR0805',
#   '2.00 ± 0.10',
#   '(.079 ± .004)',
#   '1.25 ± 0.10',
#   '(.049 ± .004)',
#   '0.40 ± 0.20',
#   '(.016 ± .008)',
#   '0.40 ± 0.20',
#   '(.016 ± .008)',
#   '0.50 ± 0.10',
#   '(.020 ± .004)',
#   'CR1206',
#   '3.10 ± 0.10',
#   '(.122 ± .004)',
#   '1.55 ± 0.10',
#   '(.061 ± .004)',
#   '0.50 ± 0.30',
#   '(.020 ± .012)',
#   '0.40 ± 0.20',
#   '(.016 ± .008)',
#   '0.55 ± 0.10',
#   '(.022 ± .004)',
#   'CR2010',
#   '5.00 ± 0.15',
#   '(.197 ± .006)',
#   '2.50 ± 0.15',
#   '(.098 ± .006)',
#   '0.60 ± 0.30',
#   '(.024 ± .012)',
#   '0.50 ± 0.25',
#   '(.020 ± .010)',
#   '0.60 ± 0.10',
#   '(.024 ± .004)',
#   'CR2512',
#   '6.30 ± 0.20',
#   '(.248 ± .008)',
#   '3.20 ± 0.20',
#   '(.126 ± .008)',
#   '0.60 ± 0.30',
#   '(.024 ± .012)',
#   '0.50 ± 0.25',
#   '(.020 ± .010)',
#   '0.60 ± 0.10',
#   '(.024 ± .004)',
#   'L',
#   'W',
#   'C',
#   'T',
#   'C',
#   'D',
#   'DIMENSIONS:',
#   'MM',
#   '(INCHES)',
#   'DIMENSIONS:',
#   'MM',
#   '(INCHES)',
#   'Recommended Pad Layout',
#   'Model',
#   'a',
#   'b',
#   'c',
#   'CR01005',
#   '0.15 ~ 0.20',
#   '(.006 ~ .008)',
#   '0.50 ~ 0.70',
#   '(.020 ~ .028)',
#   '0.20 ~ 0.25',
#   '(.008 ~ .010)',
#   'CR0201',
#   '0.25 ~ 0.30',
#   '(.010 ~ .012)',
#   '0.70 ~ 0.90',
#   '(.028 ~ .035)',
#   '0.30 ~ 0.40',
#   '(.012 ~ .016)',
#   'CR0402',
#   '0.50 ~ 0.60',
#   '(.020 ~ .024)',
#   '1.40 ~ 1.60',
#   '(.055 ~ .063)',
#   '0.40 ~ 0.60',
#   '(.012 ~ .024)',
#   'CR0603',
#   '0.70 ~ 0.90',
#   '(.028 ~ .035)',
#   '2.00 ~ 2.20',
#   '(.079 ~ .087)',
#   '0.80 ~ 1.00',
#   '(.031 ~ .039)',
#   'CR0805',
#   '1.00 ~ 1.40',
#   '(.039 ~ .055)',
#   '3.20 ~ 3.80',
#   '(.126 ~ .150)',
#   '0.90 ~ 1.40',
#   '(.035 ~ .055)',
#   'CR1206',
#   '2.00 ~ 2.40',
#   '(.079 ~ .094)',
#   '4.40 ~ 5.00',
#   '(.173 ~ .197)',
#   '1.20 ~ 1.80',
#   '(.047 ~ .071)',
#   'CR2010',
#   '3.30 ~ 3.70',
#   '(.130 ~ .146)',
#   '5.70 ~ 6.50',
#   '(.224 ± .256)',
#   '2.30 ~ 3.50',
#   '(.091 ~ .138)',
#   'CR2512',
#   '3.60 ~ 4.00',
#   '(.142 ~ .157)',
#   '7.60 ~ 8.60',
#   '(.299 ~ .339)',
#   '2.30 ~ 3.50',
#   '(.091 ~ .138)',
#   'a',
#   'RESISTOR',
#   'b',
#   'c',
#   'Speciﬁcations are subject to change without notice.',
#   'Users should verify actual device performance in their speciﬁc applications. ',
#   'The products described herein and this document are subject to speciﬁc legal disclaimers as set forth on the last page of this document, and at www.bourns.com/docs/legal/disclaimer.pdf.',
#   '\x0c ',
#   'CR Series - Thick Film Chip Resistors',
#   'Speciﬁcations are subject to change without notice.',
#   'Users should verify actual device performance in their speciﬁc applications. ',
#   'The products described herein and this document are subject to speciﬁc legal disclaimers as set forth on the last page of this document, and at www.bourns.com/docs/legal/disclaimer.pdf.',
#   'Soldering Profile',
#   '25',
#   '75',
#   '125',
#   '175',
#   '225',
#   '275',
#   '0',
#   '50',
#   '100',
#   '150',
#   '200',
#   '250',
#   '300',
#   'Time (Seconds)',
#   'Temperature (°C)',
#   '60 - 120 seconds',
#   '60 - 90',
#   'seconds',
#   '260 °C peak',
#   '190 °C',
#   '150 °C',
#   '220 °C',
#   'Ramp Down',
#   '6 °C/second',
#   '      255 °C',
#   'Maximum of 20 seconds between',
#   '        +255 °C and +260 °C',
#   'Ramp Up',
#   '3 °C/second maximum',
#   '10 seconds minimum',
#   '<1>',
#   '<1>',
#   'Derating Curve',
#   '100',
#   '80',
#   '60',
#   '40',
#   '20',
#   '0',
#   'Power Ratio (%)',
#   '-55',
#   '20',
#   '40',
#   '60',
#   '80',
#   '70',
#   '125',
#   'CR01005,',
#   'CR0201',
#   'CR0402~CR2512',
#   '155',
#   '100',
#   '120',
#   '140',
#   '160',
#   'Ambient Temperature (°C)',
#   '\x0c ',
#   'CR Series - Thick Film Chip Resistors',
#   'Performance Characteristics',
#   'Test',
#   'Procedure (IEC 60115-1)',
#   'Test Limits ∆R',
#   'Short Time Overload',
#   '2.5 x rated voltage for 5 seconds',
#   '≤± (1 % + 0.05 Ω )',
#   'Remarks:',
#   'CR01005, CR0201 .................. ± (3 % + 0.1 Ω)',
#   'CR0402 ................................... ± (2 % + 0.1 Ω)',
#   '0 Ω Jumper ................................ 50 mΩ or less',
#   'Intermittent Overload',
#   '3.0 x rated voltage or max. overloading voltage, ',
#   '1 sec. “ON”, 25 sec. “OFF”,10,000 cycles',
#   'Remarks:',
#   'CR01005, CR0201 ..................................................... not applicable',
#   'CR0402 ...............................2.5 x rated continuous working voltage',
#   '1 %: ≤± (1 % + 0.05 Ω)',
#   '5 %: ≤± (3 % + 0.1 Ω)',
#   'Remarks:',
#   'CR01005, CR0201 .................. ± (5 % + 0.1 Ω)',
#   'CR0402 ................................... ± (3 % + 0.1 Ω)',
#   '0 Ω Jumper .............................. 100 mΩ or less',
#   'Load Life',
#   '1000 hours at rated voltage, 70 ℃ , ',
#   '1.5 hours “ON “, 0.5 hour “OFF”',
#   '1 %: ≤± (1 % + 0.05 Ω)',
#   '5 %: ≤± (3 % + 0.1 Ω)',
#   'Remarks:',
#   'CR01005, CR0201 .................. ± (5 % + 0.1 Ω)',
#   'CR0402 ................................... ± (3 % + 0.1 Ω)',
#   '0 Ω Jumper .............................. 100 mΩ or less',
#   'Load Life Humidity',
#   '1000 hours at rated voltage , 40±2 ℃,',
#   '90~95 % RH 1.5 hours “ON “, 0.5 hour “OFF”',
#   '1 %: ≤± (1 % + 0.05 Ω)',
#   '5 %: ≤± (3 % + 0.1 Ω)',
#   'Remarks:',
#   'CR01005, CR0201 .................. ± (5 % + 0.1 Ω)',
#   'CR0402 ................................... ± (3 % + 0.1 Ω)',
#   '0 Ω Jumper .............................. 100 mΩ or less',
#   'Rapid Change of Temperature',
#   '-55 ℃ (30 min.) / +155 ℃ (30 min.) 5 cycles',
#   '1 %: ≤± (0.5 % + 0.05 Ω)',
#   '5 %: ≤± (1 % + 0.05 Ω)',
#   'Remarks:',
#   'CR01005, CR0201 .................. ± (3 % + 0.1 Ω)',
#   '0 Ω Jumper ................................ 50 mΩ or less',
#   'Resistance to Solder Heat',
#   '270±5 ℃, 10±1 sec.',
#   '1 %: ≤± (0.5 % + 0.05 Ω)',
#   '5 %: ≤± (1 % + 0.05 Ω)',
#   'Remarks:',
#   'CR01005 ............................... ± (3 % + 0.05 Ω)',
#   'CR0201 ................................... ± (3 % + 0.1 Ω)',
#   '0 Ω Jumper ................................ 50 mΩ or less',
#   'Solderability',
#   '245±5 ℃ solder, 2±0.5 seconds dwell',
#   'Solder: Sn96.5 / Ag3.0 / Cu0.5',
#   'Over 95 % of termination must be covered ',
#   'with solder',
#   'Resistance to Dry Heat',
#   '155±5 ℃ for 96±4 hours',
#   'Remarks:',
#   'CR0201 ............................................................................. 125±5 °C',
#   '1 %: ≤± (1 % + 0.05 Ω)',
#   '5 %: ≤± (1 % + 0.05 Ω)',
#   'Remarks:',
#   'CR01005, CR0201 .................. ± (1 % + 0.1 Ω)',
#   '0 Ω Jumper ................................ 50 mΩ or less',
#   'Bending',
#   '3 mm deflection',
#   'Remarks:',
#   'CR2010, CR2512 ....................................................2 mm deflection',
#   '1 %: ≤± (0.5 % + 0.05 Ω)',
#   '5 %: ≤± (2 % + 0.1 Ω)',
#   'Remarks:',
#   'CR01005, CR0201 .................. ± (3 % + 0.1 Ω)',
#   'CR0402 ................................... ± (2 % + 0.1 Ω)',
#   '0 Ω Jumper ................................ 50 mΩ or less',
#   'Dielectric Withstanding Voltage',
#   '500 V, 1 minute',
#   'Remarks:',
#   'CR01005, CR0201 ....................................................................50 V',
#   'CR0402 ...................................................................................300 V',
#   'No abnormalities such as flashover, burning or ',
#   'dielectric breakdown shall appear',
#   'Insulation Resistance',
#   '100 V, 1 minute',
#   'Remarks:',
#   'CR0201 .....................................................................................50 V',
#   '≥1 GΩ',
#   'Remarks:',
#   'CR01005 ..........................................≥100 MΩ)',
#   'Speciﬁcations are subject to change without notice.',
#   'Users should verify actual device performance in their speciﬁc applications. ',
#   'The products described herein and this document are subject to speciﬁc legal disclaimers as set forth on the last page of this document, and at www.bourns.com/docs/legal/disclaimer.pdf.',
#   '\x0c ',
#   'CR Series - Thick Film Chip Resistors',
#   'Speciﬁcations are subject to change without notice.',
#   'Users should verify actual device performance in their speciﬁc applications. ',
#   'The products described herein and this document are subject to speciﬁc legal disclaimers as set forth on the last page of this document, and at www.bourns.com/docs/legal/disclaimer.pdf.',
#   'How to Order',
#   'CR  1206  -  F  X  -  1003  E  LF',
#   'Model ',
#   '(CR = Chip Resistor)',
#   'Size ',
#   '  01005 = 01005 size ',
#   '0201 = 0201 size ',
#   ' ',
#   '0402  = 0402 size ',
#   ' ',
#   '0603  = 0603 size ',
#   ' ',
#   '0805  = 0805 size ',
#   ' ',
#   '1206  = 1206 size ',
#   ' ',
#   '2010  = 2010 size ',
#   ' ',
#   '2512  = 2512 size',
#   'Resistance Tolerance ',
#   ' F = ±1 %',
#   ' J = ±5 %',
#   'TCR (ppm/°C) – See Electrical Characteristics Chart ',
#   ' X =  ±100 ',
#   ' W = ±200 ',
#   ' V = ±300 ',
#   ' Z =  ±400 ',
#   ' / =  Used for zero Ω (jumper) and values from 1 Ω through 9.76 Ω.',
#   'Resistance Value ',
#   '  For 1 % Tolerance: ',
#   ' <100 Ω ..... “R” represents decimal point (example: 24R3 = 24.3 Ω). ',
#   ' ≥100 Ω  .... First three digits are significant, fourth digit represents number of zeros to follow (example: 8252 = 82.5K Ω).',
#   '  For 5 % Tolerance: ',
#   ' <10 Ω ....... “R” represents decimal point (example: 4R7 = 4.7 Ω). ',
#   ' ≥10 Ω ....... First two digits are significant, third digit represents number of zeros to follow (example: 474 = 470K Ω; 000 = Jumper).',
#   'Packaging ',
#   ' G = Paper Tape (10,000 pcs.) on 7-inch Plastic Reel – CR01005, CR0201, CR0402 ',
#   ' E = Paper Tape (5,000 pcs.) on 7-inch Plastic Reel – CR0603, CR0805, CR1206 or ',
#   '  ',
#   '  Embossed Tape (4,000 pcs) on 7-inch Plastic Reel – CR2010, CR2512',
#   'Termination ',
#   ' LF = Tin-plated (RoHS Compliant)',
#   '\x0c ',
#   'CR Series - Thick Film Chip Resistors',
#   'EIA-96 Marking for CR0603, 1 %',
#   'Code',
#   'R Value',
#   'Code',
#   'R Value',
#   'Code',
#   'R Value',
#   'Code',
#   'R Value',
#   '01',
#   '100',
#   '25',
#   '178',
#   '49',
#   '316',
#   '73',
#   '562',
#   '02',
#   '102',
#   '26',
#   '182',
#   '50',
#   '324',
#   '74',
#   '576',
#   '03',
#   '105',
#   '27',
#   '187',
#   '51',
#   '332',
#   '75',
#   '590',
#   '04',
#   '107',
#   '28',
#   '191',
#   '52',
#   '340',
#   '76',
#   '604',
#   '05',
#   '110',
#   '29',
#   '196',
#   '53',
#   '348',
#   '77',
#   '619',
#   '06',
#   '113',
#   '30',
#   '200',
#   '54',
#   '357',
#   '78',
#   '634',
#   '07',
#   '115',
#   '31',
#   '205',
#   '55',
#   '365',
#   '79',
#   '649',
#   '08',
#   '118',
#   '32',
#   '210',
#   '56',
#   '374',
#   '80',
#   '665',
#   '09',
#   '121',
#   '33',
#   '215',
#   '57',
#   '383',
#   '81',
#   '681',
#   '10',
#   '124',
#   '34',
#   '221',
#   '58',
#   '392',
#   '82',
#   '698',
#   '11',
#   '127',
#   '35',
#   '226',
#   '59',
#   '402',
#   '83',
#   '715',
#   '12',
#   '130',
#   '36',
#   '232',
#   '60',
#   '412',
#   '84',
#   '732',
#   '13',
#   '133',
#   '37',
#   '237',
#   '61',
#   '422',
#   '85',
#   '750',
#   '14',
#   '137',
#   '38',
#   '243',
#   '62',
#   '432',
#   '86',
#   '768',
#   '15',
#   '140',
#   '39',
#   '249',
#   '63',
#   '442',
#   '87',
#   '787',
#   '16',
#   '143',
#   '40',
#   '255',
#   '64',
#   '453',
#   '88',
#   '806',
#   '17',
#   '147',
#   '41',
#   '261',
#   '65',
#   '464',
#   '89',
#   '825',
#   '18',
#   '150',
#   '42',
#   '267',
#   '66',
#   '475',
#   '90',
#   '845',
#   '19',
#   '154',
#   '43',
#   '274',
#   '67',
#   '487',
#   '91',
#   '866',
#   '20',
#   '158',
#   '44',
#   '280',
#   '68',
#   '499',
#   '92',
#   '887',
#   '21',
#   '162',
#   '45',
#   '287',
#   '69',
#   '511',
#   '93',
#   '909',
#   '22',
#   '165',
#   '46',
#   '294',
#   '70',
#   '523',
#   '94',
#   '931',
#   '23',
#   '169',
#   '47',
#   '301',
#   '71',
#   '536',
#   '95',
#   '953',
#   '24',
#   '174',
#   '48',
#   '309',
#   '72',
#   '549',
#   '96',
#   '976',
#   'Multipliers',
#   'Code',
#   'A',
#   'B',
#   'C',
#   'D',
#   'E',
#   'F',
#   'G',
#   'H',
#   'X',
#   'Y',
#   'Z',
#   'Multiplier',
#   '100',
#   '101',
#   '102',
#   '103',
#   '104',
#   '105',
#   '106',
#   '107',
#   '10-1',
#   '10-2',
#   '10-3',
#   'Speciﬁcations are subject to change without notice.',
#   'Users should verify actual device performance in their speciﬁc applications. ',
#   'The products described herein and this document are subject to speciﬁc legal disclaimers as set forth on the last page of this document, and at www.bourns.com/docs/legal/disclaimer.pdf.',
#   'Marking Explanation',
#   ' 0Ω JUMPER:',
#   'CR01005, CR0201,  ',
#   'CR0402:',
#   'No marking.',
#   'CR0603, CR0805, CR1206,  ',
#   'CR2010, CR2512:',
#   '• E-24: 3 digits; first two ',
#   ' digits are significant,  ',
#   ' third digit is number of  ',
#   ' zeros to follow.',
#   ' Letter R is decimal  ',
#   ' point.',
#   '• E-96: 4 digits; first  ',
#   ' three digits are  ',
#   ' significant, fourth digit  ',
#   ' is number of zeros to  ',
#   ' follow.',
#   ' Letter R is decimal  ',
#   ' point.',
#   '• CR0603 E-96: EIA-96  ',
#   ' marking (see table).',
#   '0',
#   '103',
#   '4422',
#   '(Value = 10K Ω)',
#   '(Value = 44.2K Ω)',
#   '10C',
#   '(Value = 12.4K Ω)',
#   '\x0c ',
#   'CR Series - Thick Film Chip Resistors',
#   'Speciﬁcations are subject to change without notice.',
#   'Users should verify actual device performance in their speciﬁc applications. ',
#   'The products described herein and this document are subject to speciﬁc legal disclaimers as set forth on the last page of this document, and at www.bourns.com/docs/legal/disclaimer.pdf.',
#   'Packaging Dimensions (Conforms to EIA RS-481A)',
#   'A',
#   'T',
#   'A',
#   'A',
#   'T',
#   'T',
#   'P1',
#   'B',
#   'B',
#   'B',
#   'W',
#   'W',
#   'W',
#   'F',
#   'E',
#   'E',
#   'E',
#   'P1',
#   'P0',
#   'P2',
#   'P2',
#   'P1',
#   'P0',
#   'P2',
#   'P0',
#   'DIA.',
#   'TOP TAPE',
#   'BOTTOM TAPE',
#   'PAPER TAPE ',
#   '(2 mm PITCH)',
#   'PAPER TAPE ',
#   '(4 mm PITCH)',
#   'EMBOSSED TAPE ',
#   '(4 mm PITCH)',
#   'PAPER TAPE',
#   'RESISTOR',
#   'TOP TAPE',
#   'TOP TAPE',
#   'BOTTOM TAPE',
#   'EMBOSSED TAPE',
#   'PAPER TAPE',
#   'RESISTOR',
#   'RESISTOR',
#   'F',
#   'DIRECTION OF UNREELING',
#   'DIRECTION OF UNREELING',
#   'DIRECTION OF UNREELING',
#   'F',
#   '1.50',
#   '(.059) MIN. DIA.',
#   '1.50 ± 0.10',
#   '(.059 ± .004)',
#   '1.50 ± 0.10DIA.',
#   '(.059 ± .004)',
#   '1.50 ± 0.10DIA.',
#   '(.059 ± .004)',
#   'Model',
#   'Tape Type',
#   'A',
#   'B',
#   'W',
#   'F',
#   'E',
#   'P1',
#   'P2',
#   'P0',
#   'T',
#   'CR01005',
#   'Paper Tape  ',
#   '(2 mm pitch)',
#   '0.24 ± 0.05',
#   '(.010 ± .002)',
#   '0.45 ± 0.10',
#   '(.018 ± .004)',
#   '8.00 ± 0.20',
#   '(.315 ± .008)',
#   '3.50 ± 0.05',
#   '(.138 ± .002)',
#   '1.75 ± 0.10',
#   '(.069 ± .004)',
#   '2.00 ± 0.10',
#   '(.079 ± .004)',
#   '2.00 ± 0.05',
#   '(.079 ± .002)',
#   '4.00 ± 0.10',
#   '(.157 ± .004)',
#   '0.15 ± 0.10',
#   '(.006 ± .004)',
#   'CR0201',
#   'Paper Tape  ',
#   '(2 mm pitch)',
#   '0.37 ± 0.05',
#   '(.014 ± .002)',
#   '0.67 ± 0.10',
#   '(.026 ± .004)',
#   '0.37 ± 0.10',
#   '(.015 ± .004)',
#   'CR0402',
#   '0.70 ± 0.05',
#   '(.028 ± .002)',
#   '1.20 ± 0.05',
#   '(.047 ± .002)',
#   '0.45 ± 0.10',
#   '(.018 ± .004)',
#   'CR0603',
#   'Paper Tape (4 ',
#   'mm pitch)',
#   '1.10 ± 0.10',
#   '(.043 ± .004)',
#   '1.90 ± 0.10',
#   '(.075 ± .004)',
#   '4.00 ± 0.10',
#   '(.157 ± .004)',
#   '0.64 ± 0.10',
#   '(.025 ± .004)',
#   'CR0805',
#   '1.60 ± 0.15',
#   '(.063 ± .006)',
#   '2.40 ± 0.20',
#   '(.094 ± .008)',
#   '0.84 ± 0.10',
#   '(.033 ± .004)',
#   'CR1206',
#   '2.00 ± 0.15',
#   '(.079 ± .006)',
#   '3.60 ± 0.20',
#   '(.142 ± .008)',
#   '0.84 ± 0.10',
#   '(.033 ± .004)',
#   'CR2010',
#   'Embossed ',
#   'Tape ',
#   '(4 mm pitch)',
#   '2.80 ± 0.20',
#   '(.110 ± .008)',
#   '5.30 ± 0.20',
#   '(.209 ± .008)',
#   '12.00 ± 0.20',
#   '(.472 ± .008)',
#   '5.50 ± 0.05',
#   '(.217 ± .002)',
#   '0.85 ± 0.15',
#   '(.033 ± .006)',
#   'CR2512',
#   '3.60 ± 0.20',
#   '(.142 ± .008)',
#   '6.90 ± 0.20',
#   '(.272 ± .008)',
#   '0.85 ± 0.15',
#   '(.033 ± .006)',
#   '\x0c ',
#   'CR Series - Thick Film Chip Resistors',
#   'Packaging Dimensions (Conforms to EIA RS-481A)',
#   'A DIA.',
#   'B DIA.',
#   'W',
#   ...],
#  'lines_normalized': ['cr series thick film chip resistors',
#   'c',
#   'features',
#   'rohs compliant*',
#   'tight tolerance bottom electrode width',
#   '% % tolerance options',
#   'three layer termination process',
#   'nickel barrier helps prevent leaching',
#   'provides excellent solderability',
#   'tape reel packaging',
#   'additional information',
#   'click links information:',
#   'product',
#   'selector',
#   'technical',
#   'library',
#   'inventory',
#   'samples',
#   'contact',
#   'electrical characteristics',
#   'characteristic',
#   'model no.',
#   'cr',
#   'cr',
#   'cr',
#   'cr',
#   'cr',
#   'cr',
#   'cr',
#   'cr',
#   'power rating',
#   '@ °c',
#   '/ w',
#   '/ w',
#   '/ w',
#   '/ w',
#   '/ w',
#   '/ w',
#   '/ w',
#   'w',
#   'operating',
#   'temp. range',
#   '°c + °c',
#   '°c + °c',
#   'derated',
#   'zero load @',
#   '+ °c',
#   '+ °c',
#   'max. working',
#   'voltage',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'max. overload',
#   'voltage',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'resistance',
#   'tolerance',
#   '± %, ± %',
#   'temperature',
#   'coefficient',
#   '± %',
#   '(e & e',
#   'series)',
#   'ω≤r< ω',
#   '± ppm/°c',
#   'ω≤r< mω',
#   '± ppm/°c',
#   'ω≤r< ω',
#   '~+',
#   'ppm/°c',
#   'ω≤r≤ mω',
#   '± ppm/°c',
#   'ω≤r< ω',
#   '~+',
#   'ppm/°c',
#   'ω≤r≤ mω',
#   '± ppm/°c',
#   'mω<r≤ mω',
#   '± ppm/°c',
#   'ω≤r< ω',
#   '± ppm/°c',
#   'ω≤r≤ mω',
#   '± ppm/°c',
#   'mω<r≤ mω',
#   '± ppm/°c',
#   'ω≤r< ω',
#   '± ppm/°c',
#   'ω≤r≤ mω',
#   '± ppm/°c',
#   'mω<r≤ mω',
#   '± ppm/°c',
#   'ω≤r< ω',
#   '± ppm/°c',
#   'ω≤r≤ mω',
#   '± ppm/°c',
#   'mω<r≤ mω',
#   '± ppm/°c',
#   'ω≤r< ω',
#   '± ppm/°c',
#   'ω≤r≤ mω',
#   '± ppm/°c',
#   'mω<r≤ mω',
#   '± ppm/°c',
#   'ω≤r< ω',
#   '± ppm/°c',
#   'ω≤r≤ mω',
#   '± ppm/°c',
#   'mω<r≤ mω',
#   '± ppm/°c',
#   'temperature',
#   'coefficient',
#   '± %',
#   '(e series)',
#   'ω≤r< ω',
#   '± ppm/°c',
#   'ω≤r≤ mω',
#   '± ppm/°c',
#   'ω≤r< ω',
#   '~+',
#   'ppm/°c',
#   'ω≤r≤ mω',
#   '± ppm/°c',
#   'ω≤r< ω',
#   '~+',
#   'ppm/°c',
#   'ω≤r≤ mω',
#   '± ppm/°c',
#   'mω<r≤ mω',
#   '± ppm/°c',
#   'ω≤r< ω',
#   '± ppm/°c',
#   'ω≤r≤ mω',
#   '± ppm/°c',
#   'mω<r≤ mω',
#   '± ppm/°c',
#   'ω≤r< ω',
#   '± ppm/°c',
#   'ω≤r≤ mω',
#   '± ppm/°c',
#   'mω<r≤ mω',
#   '± ppm/°c',
#   'ω≤r< ω',
#   '± ppm/°c',
#   'ω≤r≤ mω',
#   '± ppm/°c',
#   'mω<r≤ mω',
#   '± ppm/°c',
#   'ω≤r< ω',
#   '± ppm/°c',
#   'ω≤r≤ mω',
#   '± ppm/°c',
#   'mω<r≤ mω',
#   '± ppm/°c',
#   'ω≤r< ω',
#   '± ppm/°c',
#   'ω≤r≤ mω',
#   '± ppm/°c',
#   'mω<r≤ mω',
#   '± ppm/°c',
#   'zero ohm',
#   'jumper',
#   'milliohms max.',
#   'rated current',
#   '.',
#   'max. overload',
#   'current',
#   '.',
#   'environmental characteristics',
#   'moisture sensitivity level',
#   '*rohs directive /, mar , annex.',
#   'specifications subject change without notice. users verify actual device performance specific',
#   'applications. products described herein document subject specific legal disclaimers set forth last',
#   'page document,',
#   'warning',
#   'cancer reproductive harm',
#   'cr series thick film chip resistors',
#   'product dimensions',
#   'model',
#   'l',
#   'w',
#   'c',
#   'cr',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   'cr',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   'cr',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   'cr',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   'cr',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   'cr',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   'cr',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   'cr',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   'l',
#   'w',
#   'c',
#   'c',
#   'dimensions:',
#   'mm',
#   '(inches)',
#   'dimensions:',
#   'mm',
#   '(inches)',
#   'recommended pad layout',
#   'model',
#   'b',
#   'c',
#   'cr',
#   '. ~ .',
#   '(. ~ .)',
#   '. ~ .',
#   '(. ~ .)',
#   '. ~ .',
#   '(. ~ .)',
#   'cr',
#   '. ~ .',
#   '(. ~ .)',
#   '. ~ .',
#   '(. ~ .)',
#   '. ~ .',
#   '(. ~ .)',
#   'cr',
#   '. ~ .',
#   '(. ~ .)',
#   '. ~ .',
#   '(. ~ .)',
#   '. ~ .',
#   '(. ~ .)',
#   'cr',
#   '. ~ .',
#   '(. ~ .)',
#   '. ~ .',
#   '(. ~ .)',
#   '. ~ .',
#   '(. ~ .)',
#   'cr',
#   '. ~ .',
#   '(. ~ .)',
#   '. ~ .',
#   '(. ~ .)',
#   '. ~ .',
#   '(. ~ .)',
#   'cr',
#   '. ~ .',
#   '(. ~ .)',
#   '. ~ .',
#   '(. ~ .)',
#   '. ~ .',
#   '(. ~ .)',
#   'cr',
#   '. ~ .',
#   '(. ~ .)',
#   '. ~ .',
#   '(. ± .)',
#   '. ~ .',
#   '(. ~ .)',
#   'cr',
#   '. ~ .',
#   '(. ~ .)',
#   '. ~ .',
#   '(. ~ .)',
#   '. ~ .',
#   '(. ~ .)',
#   'resistor',
#   'b',
#   'c',
#   'speciﬁcations subject change without notice.',
#   'users verify actual device performance speciﬁc applications.',
#   'products described herein document subject speciﬁc legal disclaimers set forth last page document,',
#   'cr series thick film chip resistors',
#   'speciﬁcations subject change without notice.',
#   'users verify actual device performance speciﬁc applications.',
#   'products described herein document subject speciﬁc legal disclaimers set forth last page document,',
#   'soldering profile',
#   'time (seconds)',
#   'temperature (°c)',
#   'seconds',
#   'seconds',
#   '°c peak',
#   '°c',
#   '°c',
#   '°c',
#   'ramp',
#   '°c/second',
#   '°c',
#   'maximum seconds',
#   '+ °c + °c',
#   'ramp',
#   '°c/second maximum',
#   'seconds minimum',
#   '<>',
#   '<>',
#   'derating curve',
#   'power ratio (%)',
#   'cr,',
#   'cr',
#   'cr~cr',
#   'ambient temperature (°c)',
#   'cr series thick film chip resistors',
#   'performance characteristics',
#   'test',
#   'procedure (iec )',
#   'test limits ∆r',
#   'short time overload',
#   '. x rated voltage seconds',
#   '≤± ( % + . ω )',
#   'remarks:',
#   'cr, cr .................. ± ( % + . ω)',
#   'cr ± ( % + . ω)',
#   'ω jumper mω less',
#   'intermittent overload',
#   '. x rated voltage max. overloading voltage,',
#   'sec. “on”, sec. “off”,, cycles',
#   'remarks:',
#   'cr, cr applicable',
#   'cr x rated continuous working voltage',
#   '%: ≤± ( % + . ω)',
#   '%: ≤± ( % + . ω)',
#   'remarks:',
#   'cr, cr .................. ± ( % + . ω)',
#   'cr ± ( % + . ω)',
#   'ω jumper mω less',
#   'load life',
#   'hours rated voltage, ℃ ,',
#   '. hours “on “, . hour “off”',
#   '%: ≤± ( % + . ω)',
#   '%: ≤± ( % + . ω)',
#   'remarks:',
#   'cr, cr .................. ± ( % + . ω)',
#   'cr ± ( % + . ω)',
#   'ω jumper mω less',
#   'load life humidity',
#   'hours rated voltage , ± ℃,',
#   '~ % rh . hours “on “, . hour “off”',
#   '%: ≤± ( % + . ω)',
#   '%: ≤± ( % + . ω)',
#   'remarks:',
#   'cr, cr .................. ± ( % + . ω)',
#   'cr ± ( % + . ω)',
#   'ω jumper mω less',
#   'rapid change temperature',
#   '℃ ( min.) / + ℃ ( min.) cycles',
#   '%: ≤± (. % + . ω)',
#   '%: ≤± ( % + . ω)',
#   'remarks:',
#   'cr, cr .................. ± ( % + . ω)',
#   'ω jumper mω less',
#   'resistance solder heat',
#   '± ℃, ± sec.',
#   '%: ≤± (. % + . ω)',
#   '%: ≤± ( % + . ω)',
#   'remarks:',
#   'cr ± ( % + . ω)',
#   'cr ± ( % + . ω)',
#   'ω jumper mω less',
#   'solderability',
#   '± ℃ solder, ±. seconds dwell',
#   'solder: sn. / ag. / cu.',
#   '% termination must covered',
#   'solder',
#   'resistance dry heat',
#   '± ℃ ± hours',
#   'remarks:',
#   'cr ± °c',
#   '%: ≤± ( % + . ω)',
#   '%: ≤± ( % + . ω)',
#   'remarks:',
#   'cr, cr .................. ± ( % + . ω)',
#   'ω jumper mω less',
#   'bending',
#   'mm deflection',
#   'remarks:',
#   'cr, cr mm deflection',
#   '%: ≤± (. % + . ω)',
#   '%: ≤± ( % + . ω)',
#   'remarks:',
#   'cr, cr .................. ± ( % + . ω)',
#   'cr ± ( % + . ω)',
#   'ω jumper mω less',
#   'dielectric withstanding voltage',
#   'v, minute',
#   'remarks:',
#   'cr, cr v',
#   'cr v',
#   'abnormalities flashover, burning',
#   'dielectric breakdown shall appear',
#   'insulation resistance',
#   'v, minute',
#   'remarks:',
#   'cr v',
#   '≥ gω',
#   'remarks:',
#   'cr mω)',
#   'speciﬁcations subject change without notice.',
#   'users verify actual device performance speciﬁc applications.',
#   'products described herein document subject speciﬁc legal disclaimers set forth last page document,',
#   'cr series thick film chip resistors',
#   'speciﬁcations subject change without notice.',
#   'users verify actual device performance speciﬁc applications.',
#   'products described herein document subject speciﬁc legal disclaimers set forth last page document,',
#   'order',
#   'cr f x e lf',
#   'model',
#   '(cr = chip resistor)',
#   'size',
#   '= size',
#   '= size',
#   '= size',
#   '= size',
#   '= size',
#   '= size',
#   '= size',
#   '= size',
#   'resistance tolerance',
#   'f = ± %',
#   'j = ± %',
#   'tcr (ppm/°c) – see electrical characteristics chart',
#   'x = ±',
#   'w = ±',
#   'v = ±',
#   'z = ±',
#   '/ = used zero ω (jumper) values ω . ω.',
#   'resistance value',
#   '% tolerance:',
#   '< ω ..... “r” represents decimal point (example: r = . ω).',
#   '≥ ω .... first three digits significant, fourth digit represents number zeros follow (example: = .k ω).',
#   '% tolerance:',
#   '< ω ....... “r” represents decimal point (example: r = . ω).',
#   '≥ ω ....... first two digits significant, third digit represents number zeros follow (example: = k ω; = jumper).',
#   'packaging',
#   'g = paper tape (, pcs.) inch plastic reel – cr, cr, cr',
#   'e = paper tape (, pcs.) inch plastic reel – cr, cr, cr',
#   'embossed tape (, pcs) inch plastic reel – cr, cr',
#   'termination',
#   'lf = tin plated (rohs compliant)',
#   'cr series thick film chip resistors',
#   'eia marking cr, %',
#   'code',
#   'r value',
#   'code',
#   'r value',
#   'code',
#   'r value',
#   'code',
#   'r value',
#   'multipliers',
#   'code',
#   'b',
#   'c',
#   'e',
#   'f',
#   'g',
#   'h',
#   'x',
#   'z',
#   'multiplier',
#   'speciﬁcations subject change without notice.',
#   'users verify actual device performance speciﬁc applications.',
#   'products described herein document subject speciﬁc legal disclaimers set forth last page document,',
#   'marking explanation',
#   'ω jumper:',
#   'cr, cr,',
#   'cr:',
#   'marking.',
#   'cr, cr, cr,',
#   'cr, cr:',
#   'e : digits; first two',
#   'digits significant,',
#   'third digit number',
#   'zeros follow.',
#   'letter r decimal',
#   'point.',
#   'e : digits; first',
#   'three digits',
#   'significant, fourth digit',
#   'number zeros',
#   'follow.',
#   'letter r decimal',
#   'point.',
#   'cr e : eia',
#   'marking (see table).',
#   '(value = k ω)',
#   '(value = .k ω)',
#   'c',
#   '(value = .k ω)',
#   'cr series thick film chip resistors',
#   'speciﬁcations subject change without notice.',
#   'users verify actual device performance speciﬁc applications.',
#   'products described herein document subject speciﬁc legal disclaimers set forth last page document,',
#   'packaging dimensions (conforms eia rs a)',
#   'p',
#   'b',
#   'b',
#   'b',
#   'w',
#   'w',
#   'w',
#   'f',
#   'e',
#   'e',
#   'e',
#   'p',
#   'p',
#   'p',
#   'p',
#   'p',
#   'p',
#   'p',
#   'p',
#   'dia.',
#   'top tape',
#   'bottom tape',
#   'paper tape',
#   '( mm pitch)',
#   'paper tape',
#   '( mm pitch)',
#   'embossed tape',
#   '( mm pitch)',
#   'paper tape',
#   'resistor',
#   'top tape',
#   'top tape',
#   'bottom tape',
#   'embossed tape',
#   'paper tape',
#   'resistor',
#   'resistor',
#   'f',
#   'direction unreeling',
#   'direction unreeling',
#   'direction unreeling',
#   'f',
#   '.',
#   '(.) min. dia.',
#   '. ± .',
#   '(. ± .)',
#   '. ± .dia.',
#   '(. ± .)',
#   '. ± .dia.',
#   '(. ± .)',
#   'model',
#   'tape type',
#   'b',
#   'w',
#   'f',
#   'e',
#   'p',
#   'p',
#   'p',
#   'cr',
#   'paper tape',
#   '( mm pitch)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   'cr',
#   'paper tape',
#   '( mm pitch)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   'cr',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   'cr',
#   'paper tape (',
#   'mm pitch)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   'cr',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   'cr',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   'cr',
#   'embossed',
#   'tape',
#   '( mm pitch)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   'cr',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   'cr series thick film chip resistors',
#   'packaging dimensions (conforms eia rs a)',
#   'dia.',
#   'b dia.',
#   'w',
#   'c dia.',
#   'model',
#   'packaging quantity',
#   'b',
#   'c',
#   'w',
#   'cr',
#   'k pcs./reel',
#   '± .',
#   '(. ± .)',
#   '± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   'cr',
#   'cr',
#   'cr',
#   'k pcs./reel',
#   'cr',
#   'cr',
#   'cr',
#   'k pcs./reel',
#   '. ± .',
#   '(. ± .)',
#   '. ± .',
#   '(. ± .)',
#   'cr',
#   'dimensions:',
#   'mm',
#   '(inches)',
#   'speciﬁcations subject change without notice.',
#   'users verify actual device performance speciﬁc applications.',
#   'products described herein document subject speciﬁc legal disclaimers set forth last page document,',
#   'rev. /',
#   'asia pacific: tel: + email: asiacus@bourns.com',
#   'emea: tel: + email: eurocus@bourns.com',
#   'americas: tel: + email: americus@bourns.com',
#   'legal disclaimer notice',
#   'legal disclaimer applies purchasers users bourns® products manufactured behalf bourns, inc.',
#   'unless otherwise expressly indicated writing, bourns® products data sheets relating thereto subject change',
#   'complete placing orders bourns® products.',
#   'characteristics parameters bourns® product set forth data sheet based laboratory conditions,',
#   'statements regarding suitability products certain types applications based bourns’ knowledge typical',
#   'requirements generic applications. characteristics parameters',
#   'product components',
#   'actual performance',
#   'product meeting requirements particular industry',
#   'bourns® products responsible ensuring compliance safety related requirements standards applicable',
#   'case case basis, use',
#   'standard products suitable use aircraft',
#   'standard',
#   'user’s sole risk.',
#   'custom products shall negotiated case case basis bourns',
#   'user',
#   'standard products shall',
#   'also apply bourns® custom products.',
#   'users shall sell, transfer, export export',
#   'products bourns technology technical data may circumstance',
#   'exported exported countries subject international sanctions embargoes. bourns® products may not, without',
#   'bilingual versions available at:',
#   'web page: terms policies',
#   'pdf:'],
#  'n_lines': 1108,
#  'n_lines_normalized': 792,
#  'n_tokens': 2195,
#  'urls': ['http://www.bourns.com/docs/Legal/disclaimer.pdf',
#   'http://www.bourns.com/legal/disclaimers-terms-and-policies',
#   'www.P65Warnings.ca.gov',
#   'www.bourns.com',
#   'www.bourns.com/docs/legal/disclaimer.pdf'],
#  'n_urls': 5,
#  'numbers': ['0',
#   '00',
#   '000',
#   '0008',
#   '001',
#   '002',
#   '004',
#   '006',
#   '008',
#   '009',
#   '010',
#   '01005',
#   '010050',
#   '0100510',
#   '01034422',
#   '...',
#   '012',
#   '013',
#   '014',
#   '015',
#   '016',
#   '018',
#   '02',
#   '020',
#   '0201',
#   '02010',
#   '022',
#   '024',
#   '025',
#   '026',
#   '028',
#   '03',
#   '031',
#   '033',
#   '035',
#   '039',
#   '0402',
#   '04020',
#   '04021',
#   '043',
#   '047',
#   '049',
#   '05',
#   '055',
#   '059',
#   '0603',
#   '06030',
#   '06031',
#   '06035',
#   '061',
#   '063',
#   '069',
#   '071',
#   '075',
#   '079',
#   '0805',
#   '08051',
#   '08052',
#   '087',
#   '091',
#   '094',
#   '098',
#   '1',
#   '10',
#   '100',
#   '1000',
#   '10010110210310410510610710',
#   '1003',
#   '100806040200',
#   '11',
#   '110',
#   '12',
#   '120',
#   '1206',
#   '12062',
#   '12063',
#   '122',
#   '125',
#   '126',
#   '13',
#   '130',
#   '138',
#   '142',
#   '146',
#   '15',
#   '150',
#   '155',
#   '157',
#   '16',
#   '173',
#   '178',
#   '190',
#   '197',
#   '2',
#   '20',
#   '200',
#   '2010',
#   '20103',
#   '20104',
#   '20105',
#   '2015',
#   '209',
#   '21',
#   '210',
#   '217',
#   '220',
#   '224',
#   '23',
#   '24',
#   '245',
#   '248',
#   '25',
#   '2512',
#   '2512155100120140160',
#   '25123',
#   '25126',
#   '255',
#   '256',
#   '2562',
#   '2575125175225275050100150200250300',
#   '260',
#   '270',
#   '272',
#   '299',
#   '3',
#   '30',
#   '300',
#   '31',
#   '315',
#   '32',
#   '339',
#   '354',
#   '36',
#   '362',
#   '37',
#   '4',
#   '40',
#   '400',
#   '4117',
#   '44',
#   '45',
#   '453',
#   '470',
#   '472',
#   '474',
#   '481',
#   '5',
#   '50',
#   '500',
#   '512',
#   '55',
#   '5500',
#   '552040608070125',
#   '6',
#   '60',
#   '600',
#   '60115',
#   '610',
#   '64',
#   '65',
#   '67',
#   '7',
#   '70',
#   '75',
#   '76',
#   '781',
#   '8',
#   '80',
#   '82',
#   '8252',
#   '84',
#   '85',
#   '863',
#   '877',
#   '88',
#   '885',
#   '886',
#   '9',
#   '90',
#   '95',
#   '951',
#   '96'],
#  'n_numbers': 182,
#  'keywords_counts_dict': {'ESR': 1,
#   'Ω': 150,
#   'power rating': 1,
#   'dielectric': 2,
#   'resistance': 6,
#   'GΩ': 1,
#   'nF': 4,
#   'MΩ': 49,
#   'Ohm ': 1},
#  'keywords': ['ESR',
#   'Ω',
#   'power rating',
#   'dielectric',
#   'resistance',
#   'GΩ',
#   'nF',
#   'MΩ',
#   'Ohm '],
#  'n_keywords': 215,
#  'negative_keywords_counts_dict': {},
#  'negative_keywords': [],
#  'n_negative_keywords': 0}

# %%
non_data_sheets = '''
https://app.ikido.tech/api/datasheet/91e2e96faeb83845a3aecd3bb009ca251ff8518b3177e75a6babc1755441d85eac4541518fb9fb7f9c6f2d0a3baabc69b2e6885e32e8457b911acb76f6822c1a/3723731.pdf
https://app.ikido.tech/api/datasheet/5ede82d7ace65b93ebd6a276320c5103ab5f7bf0bf755a89d1b491a62e5c6713e444a5e80dee85bc0c4cf1ae85f61eb64291e920725057cdec9c1b4c48e0cf31/UMS_TD-1817076.pdf
https://app.ikido.tech/api/datasheet/721347d6220d32c4036fbfecbc60040721415864320f95b3193de6e3f2a9146d5c3879f8c2879f6b724e022d0288ef415be7f5328936d5d8090704fa2cd07ca9/096X00X9XXX_100793383DRW001A-1492629.pdf
https://app.ikido.tech/api/datasheet/a24e4241c4dc110839d95fa00eea0b7b136d4a1f1a8755cb048dee3f67a002e608ba0c0301754f433d3ebb1334127fec78654cacfde3bb6a1b10c874ae71a519/3742689.pdf
https://app.ikido.tech/api/datasheet/6af869bc5c161d6df3b2b328df6685668ad66a1159c80f3d0d561e7906bd7b74185db8d18727d8fec33cc208f0fc201d679b32d962ee04c64ab4b24f540c1db1/SFS0_440_Y_NR-1878758.pdf
https://app.ikido.tech/api/datasheet/a24b1a87bc3804d1cbe60aff09ee856ef5bfbf085399ad07c6cc46a11d70c76d30095b455251a3d19d1a0ea3ed3b4f5d23c718b386904bbe87ade676041fe3b1/84.pdf
https://app.ikido.tech/api/datasheet/233f8b7e6cf7fb2e8a70a0deb98f5714b5ee8b9580b1475b49dfa515801c6eb0f128af6d8a5db11b0fc22d5fc9c2e390f6806d7c20f92f9fbf714af6b9a8727c/delphi_03132018_15409817_cus01_s01-tif-1360617.pdf
https://app.ikido.tech/api/datasheet/b4827501efa2c5424314655ac389bb28d037a5635809c05b2cc20c580e2be2c57733d73c8d1ef9be782aeee6c7226ce4fde814d32e84e84b75aeb4d9d4cccb6a/LUMXD00016_24-2551123.pdf
https://app.ikido.tech/api/datasheet/b74d2cd415b1aa7fbe38262ce894378376b9aa8634fe00d99b326673010827059f17656a9bbed4d652c2738dcaf509e028f26a9e53f37e8ac4799a9e1e85fd63/LUMXS07437_1-2551399.pdf
https://app.ikido.tech/api/datasheet/d0c6780161ca3d0cf041dd841bc61c2b2a55b1b7b28b4650cf1d24b17c85ab77bf567d95ba621ad9cbed8945f7eda82332b6ed3d9bf14e0030954bd169222d1b/dr-MAG-0826-1G1T-23-F-1661083.pdf
https://app.ikido.tech/api/datasheet/add2a147e9639ee4be1f58c164ef812a4bebbf292ea8a5e50ecce3c470c85c7a270b72e3817efb5a0fd71b741c7300e07e652a243cebaa487dae853bea344473/8465-742875.pdf
https://app.ikido.tech/api/datasheet/c9aed0a8e6627741ea079aabf1766f79ddec980b399599dc4376fffd729f986f87d4e6d1e33adc157d59f8f18c23ed34c94eb2959f2da5825ab68e06f39c6782/5285_5289-2013653.pdf
https://app.ikido.tech/api/datasheet/41f5b69a61bbd3199957d68601b82ae6f775f8b8145954c83bd8a331b0dadc63046e325499271a4793252a870cd084a88b8efad2e2a21afe0f223925d9e827d5/3213136.pdf
https://app.ikido.tech/api/datasheet/213cddb982aa2dbff7e98eb002c8de0d4b50d9cc7d8a2bd1dc08525a6787d8aef1bc6d60ecd5cacf5428eb2d4811a910ed29b1037ebd1b47d7244f327937efda/91342081-1671997.pdf'''

non_data_sheets = [i for i in non_data_sheets.split('\n') if i]

data_sheets = '''
https://app.ikido.tech/api/datasheet/537873cbbf28b61d7fe4967b59840a67488f8f6e60175b26c5945946f9297146c00f21e9e48b8fb8ec169e3a36d29bb280e06e5dc0c7640880052693db743755/cr.pdf
https://app.ikido.tech/api/datasheet/c57f6038c22cf9f38d02b4b911f91f1ba4e80e7f09c5d043892405da065aa715e7b81ac181fbe515afb842c3a0d8f6556e80396dc5171be7135ae8757a0611bb/3920709.pdf
https://app.ikido.tech/api/datasheet/f23548e6808eca66f688dcc831df4585bab09ce1e8078fa25adcd03a55b0d132eaa772ecc6aa75c2901b076a145fb4ce4a1192bc0522f1ba61a5e9d17c60e0e9/JELF243A_0050-1380872.pdf
https://app.ikido.tech/api/datasheet/733dbcd03aec6fc8401d1ccdb022c5029e5dc4fd04f72d6f25a8b990c022f5902adcd77bf9c8e744c69d53a1a03f103fec6acbe94c8d99e440c6aeb0f17b4250/1912884.pdf
https://app.ikido.tech/api/datasheet/ad680504d0ac8acf2636579c7a5819ce7691104830e24af020407b75d156f928251dad318fba77b0b569b5883cdded57e492a28f11395b8488c33fabf9e00ba3/ESD9101-D.PDF
https://app.ikido.tech/api/datasheet/287d7e146726a1a8b0b268a343152d8ee0e2847a477f3e53a03b96735ddb2883dd7a085df7edea29d1f490b32a8de5fe390f9eee669f1dba1bd67aef2a091989/598-8410-207F-Dialight-datasheet-148081.pdf
https://app.ikido.tech/api/datasheet/d4d76898e1e2c1d3523d93eebe30df4deab37d37e49362206fcfb1902a207e2ff9b4f02a752008f8873bb0ef22b361d69dc86173ca5c2b14ae527784c4206bb9/P6SMB82CAT3G-ON-Semiconductor-datasheet-5314720.pdf
https://app.ikido.tech/api/datasheet/c279f0a8e019a9493032bc76d9300cff1aa0299290bf4a9bc04e4d5a98e4ca7501315490d2168fbdddc4b10b9056f2d6319071b79a606040b7f54a53896832ec/PXARA-e.PDF
https://app.ikido.tech/api/datasheet/0778cc7ead08b40efe3ab60261581fff57636eaa48b5f7979968f877a83fe730c94920809d6d7a7ccb5d85cd2e14b974e7c9c7bb13e1c5c13c9c56a36c3d04e0/UNCH_S_Z0000002162_1-2524880.pdf
https://app.ikido.tech/api/datasheet/cea6c1a02cc079345cd86deab8f0f715e61b71cfb5560bed922e357992f6dff0ca32fc27ea23251bac8760d1e0aca74a20de1aa515839972bd15991b7532b940/AM3G-NZ.pdf
https://app.ikido.tech/api/datasheet/537873cbbf28b61d7fe4967b59840a67488f8f6e60175b26c5945946f9297146c00f21e9e48b8fb8ec169e3a36d29bb280e06e5dc0c7640880052693db743755/cr.pdf
https://app.ikido.tech/api/datasheet/34768633a6690d049c95082bcb5868122f0d61a58e0d97579e282008385cdec26ba3c7643f6ca3ac818a4e9402d15368de49f714bf484dae3fd1c03e25f734e3/cr-1858361.pdf
https://app.ikido.tech/api/datasheet/537873cbbf28b61d7fe4967b59840a67488f8f6e60175b26c5945946f9297146c00f21e9e48b8fb8ec169e3a36d29bb280e06e5dc0c7640880052693db743755/cr.pdf
https://app.ikido.tech/api/datasheet/5417e13e19d4ebce7125f17af58b726a6969398fb92a071b6da8421421291efdac50368f70509bcb36dcf5ba88f1e912410dac2626beb3923cb7bce74f63df48/CRxxxxx.pdf
https://app.ikido.tech/api/datasheet/34768633a6690d049c95082bcb5868122f0d61a58e0d97579e282008385cdec26ba3c7643f6ca3ac818a4e9402d15368de49f714bf484dae3fd1c03e25f734e3/cr-1858361.pdf
'''

data_sheets = [i for i in data_sheets.split('\n') if i]

# %%
# pdf_datasheet_url = 'https://app.ikido.tech/api/datasheet/9cd85784796b00d29e76deaefc9f8ad43a9c199b268a953546b6027c572e9c6d0713fd4b62cfaf3cb3c0ac07f477668c088f63562542db5ececb7627258d84e7/KEM_T2005_T491-1093550.pdf'
inputs = []
for i in range(10):
    if i <5:
        inputs.append({'pdf_datasheet_url':data_sheets[i]})
    else:
        inputs.append({'pdf_datasheet_url':non_data_sheets[i-5]}) 



out = pipeline(inputs = inputs)

# %%
out
# Out:
# ['{"label": "Resistors", "score": 0.9961407780647278, "version": "1.0.0", "forced": false, "forced_reason": "Did Not Forced", "predictor_label": "Resistors"}',
#  '{"label": "Not Sure", "score": 0.8977808356285095, "version": "1.0.0", "forced": true, "forced_reason": "prediction score is 0.8977808356285095 < predefined threshold (0.99)", "predictor_label": "Leds"}',
#  '{"label": "Inductors", "score": 0.9907696843147278, "version": "1.0.0", "forced": false, "forced_reason": "Did Not Forced", "predictor_label": "Inductors"}',
#  '{"label": "Non Datasheet", "score": -1.0, "version": "1.0.0", "forced": true, "forced_reason": "Number of tokens is too low (6) < (100)", "predictor_label": "Non Datasheet"}',
#  '{"label": "Diodes", "score": 0.9971000552177429, "version": "1.0.0", "forced": false, "forced_reason": "Did Not Forced", "predictor_label": "Diodes"}',
#  '{"label": "Non Datasheet", "score": -1.0, "version": "1.0.0", "forced": true, "forced_reason": "More negative keywords than pages (NK = 16) > (P = 2)", "predictor_label": "Non Datasheet"}',
#  '{"label": "Non Datasheet", "score": -1.0, "version": "1.0.0", "forced": true, "forced_reason": "Number of tokens is too low (17) < (100)", "predictor_label": "Non Datasheet"}',
#  '{"label": "Non Datasheet", "score": -1.0, "version": "1.0.0", "forced": true, "forced_reason": "Number of tokens is too low (28) < (100)", "predictor_label": "Non Datasheet"}',
#  '{"label": "Non Datasheet", "score": -1.0, "version": "1.0.0", "forced": true, "forced_reason": "More negative keywords than pages (NK = 17) > (P = 3)", "predictor_label": "Non Datasheet"}',
#  '{"label": "Non Datasheet", "score": -1.0, "version": "1.0.0", "forced": true, "forced_reason": "Number of tokens is too low (23) < (100)", "predictor_label": "Non Datasheet"}']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=['number_of_pages', 'n_numbers', 'n_lines', 'n_tokens', 'n_negative_keywords',  'n_keywords', 'n_images', 'n_chapters', 'negative_keywords', 'keywords','label', 'score', 'text'])

for p in pipeline.preprocessor.predictables:
    row = [p.features.number_of_pages, p.features.n_numbers,p.features.n_lines_normalized, p.features.n_tokens,  p.features.n_negative_keywords, p.features.n_keywords, p.features.n_images, len(p.features.table_of_content), p.features.negative_keywords, p.features.keywords, p.category_label, p.category_score, p.features.raw_text[:1000]]
    df.loc[len(df)] = row

# %%
5/3
# Out:
# 1.6666666666666667

# %%
df.head(10)
# Out:
#   number_of_pages n_numbers n_lines n_tokens n_negative_keywords n_keywords  \
# 0               9       182     792     2195                   0        215
# 1               3       169     404      270                   0          4
# 2              16       120    1816     5397                   0         60
# 3               1         2       3        6                   0          0
# 4               8       142     574     1803                   0         33
# 5               2        41     109      490                  16          3
# 6               2         4       5       17                   0          1
# 7               3        14       4       28                   0          1
# 8               3        24     115      471                  15          6
# 9               2         9       6       23                   0          1
#
#   n_images n_chapters                                  negative_keywords  \
# 0        1          0                                                 []
# 1        6          0                                                 []
# 2       15          0                                                 []
# 3        0          0                                                 []
# 4        3          0                                                 []
# 5        2          0  [process change notification, pcn, title of ch...
# 6        0          0                                                 []
# 7        0          0                                                 []
# 8        3          0  [pcn, announcement of change(s), announcement ...
# 9        0          0                                                 []
#
#                                             keywords          label     score  \
# 0  [resistance, dielectric, GΩ, Ohm , power ratin...      Resistors  0.999149
# 1                                  [nF, part number]     Connectors  0.990770
# 2   [resistance, inductance, mH, Ω, nF, part number]      Inductors  0.988524
# 3                                                 []  Non Datasheet -1.000000
# 4  [resistance, gain, pin configuration, capacita...         Diodes  0.997202
# 5                                  [nF, part number]  Non Datasheet -1.000000
# 6                                               [nF]  Non Datasheet -1.000000
# 7                                               [nF]  Non Datasheet -1.000000
# 8                              [pF, nF, part number]  Non Datasheet -1.000000
# 9                                               [nF]  Non Datasheet -1.000000
#
#                                                 text
# 0  CR Series - Thick Film Chip Resistors10CFeatur...
# 1  Product Group: SIL/Wed Jan 25, 2023/PIN-SIL-00...
# 2  Spec No.: JELF243A_0050AC-01 P1/15 MURATA MFG ...
# 3   PDS: Rev :RSTATUS:ReleasedPrinted:  Feb 17, 2015
# 4  ©  Semiconductor Components Industries, LLC, 2...
# 5     Final Product/Process Change Notification D...
# 6    Mouser Electronics   Authorized Distributor ...
# 7    Mouser Electronics   Authorized Distributor ...
# 8   _____________________________________________...
# 9    Mouser Electronics   Authorized Distributor ...

# %%
p =  pipeline.preprocessor.predictables[1]
p.features.n_images
# Out:
# 4
